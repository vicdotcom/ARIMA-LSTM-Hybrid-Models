# %%
## (Python 3.12.0)

## Common libraries 
import numpy as np
import pandas as pd
import pandas_ta as ta # Technical indicator library

## Visualization
import matplotlib.pyplot as plt
import seaborn as sns

## Datetime
import datetime as dt
from datetime import timedelta

## Libraires for ARIMA
import statsmodels # Statistical package
from statsmodels.tsa.arima.model import ARIMA
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
from statsmodels.tsa.stattools import adfuller # ADF test for stationarity
from statsmodels.tsa.stattools import arma_order_select_ic 
import pmdarima as pm # auto_arima (does not work with recent Python versions)

## sklearn libraries
from sklearn.preprocessing import Normalizer, MinMaxScaler # Data transformation
from sklearn.metrics import mean_squared_error, root_mean_squared_error, mean_absolute_error, mean_absolute_percentage_error, r2_score # Metrics
from sklearn.feature_selection import RFE # RFE Feature selection

## XGBoost for RFE Feature Selection
from xgboost import XGBRegressor

## Neural network library
from tensorflow import keras
from tensorflow.keras.models import Sequential
from tensorflow.keras.models import load_model
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.layers import Dense, Dropout, LSTM, Activation, Input
from keras.callbacks import EarlyStopping, ReduceLROnPlateau
from tensorflow.keras import regularizers # Regularization during training
import keras_tuner # Hyperparameter tuning
from keras_tuner.tuners import RandomSearch

import warnings
warnings.filterwarnings('ignore')

import gc

# %%
## Import the data
link= "https://raw.githubusercontent.com/vicdotcom/My-Datasets/refs/heads/main/SCOM.csv"

data= pd.read_csv(link)
# Convertng to datetime
data['Date']= pd.to_datetime(data['Date'])

# Sort from earliest to latest
data= data.reindex(index= data.index[::-1])
data.reset_index(inplace= True)
data.drop(['index'], axis= 1, inplace= True)

# Remove whitespace from columns
data.columns= data.columns.str.strip()

print(data.columns)
data.head(10)
# Out:
# Index(['Date', 'Open', 'High', 'Low', 'Close', 'Volume'], dtype='object')
#         Date  Open  High   Low  Close    Volume
# 0 2010-01-04  4.55  4.55  4.55   4.55   2802800
# 1 2010-01-05  4.55  4.60  4.60   4.60   1965900
# 2 2010-01-06  4.60  4.80  4.80   4.80   3856500
# 3 2010-01-07  4.80  4.95  4.95   4.95  22382600
# 4 2010-01-08  4.95  5.00  5.00   5.00  37595102
# 5 2010-01-11  5.00  5.05  5.05   5.05  20471900
# 6 2010-01-12  5.05  5.15  5.15   5.15  52153000
# 7 2010-01-13  5.15  5.40  5.40   5.40  31640600
# 8 2010-01-14  5.40  5.75  5.75   5.75  34234301
# 9 2010-01-15  5.75  5.55  5.55   5.55  27798801

# %%
prices= data['Close']

# %% [markdown]
# ### Fitting an Ideal ARIMA Model
# Fitting refers to the process of estimating the ARIMA(p,d,q) parameters. We shall do this via grid search.
#
# For starters, consider a simple ARIMA(1,1,1) as a control.

# %%
## Splitting
n= 15 # No of days we will predict into the future

arima_train, arima_test= prices[:-n], prices[-n:]

# %%
autoARIMA= pm.auto_arima(arima_train, d=1, 
                         start_P= 0, start_q= 0, 
                         max_p= 10, max_q= 10,
                         information_criterion= 'aic',
                         error_action= 'ignore', # Ignore orders that don't work
                         stepwise= False)

# %%
## Release unwanted memory after a computationally heavy task
gc.collect()
# Out:
# 127

# %%
print(autoARIMA.summary())
# Out:
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                 3797
# Model:               SARIMAX(4, 1, 1)   Log Likelihood               -1183.121
# Date:                Sun, 03 Aug 2025   AIC                           2380.242
# Time:                        20:12:03   BIC                           2423.934
# Sample:                             0   HQIC                          2395.771
#                                - 3797
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# intercept      0.0013      0.002      0.623      0.533      -0.003       0.005
# ar.L1          0.8550      0.101      8.463      0.000       0.657       1.053
# ar.L2         -0.2191      0.024     -8.977      0.000      -0.267      -0.171
# ar.L3          0.0428      0.015      2.878      0.004       0.014       0.072
# ar.L4         -0.0399      0.013     -3.070      0.002      -0.065      -0.014
# ma.L1         -0.6392      0.101     -6.341      0.000      -0.837      -0.442
# sigma2         0.1092      0.001     90.416      0.000       0.107       0.112
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.00   Jarque-Bera (JB):              7281.26
# Prob(Q):                              0.98   Prob(JB):                         0.00
# Heteroskedasticity (H):              18.65   Skew:                            -0.07
# Prob(H) (two-sided):                  0.00   Kurtosis:                         9.78
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).

# %%
autoARIMA.plot_diagnostics(figsize= (10,9))

# %% [markdown]
# ### Predictions

# %%
len(arima_train)
# Out:
# 3797

# %%
## In sample predictions
autoARIMA_forecast= autoARIMA.predict_in_sample()

autoARIMA_forecast
# Out:
# 0        0.003499
# 1        4.553499
# 2        4.613008
# 3        4.843181
# 4        4.970010
#           ...
# 3792    18.170618
# 3793    17.258004
# 3794    17.841050
# 3795    17.993693
# 3796    18.086747
# Name: predicted_mean, Length: 3797, dtype: float64

# %%
## Predicting for the next n days (length of the test data)

# Forecasts
autoARIMA_pred= autoARIMA.predict(n_periods= n)
 # .predict() is used as autoARIMA is a pmdarima object
 # otherwise .get_forecast(steps= n) would be used

# Confidence interval
autoARIMA_limits= autoARIMA.conf_int()

# Predicted values
autoARIMA_pred.head()
# Out:
# 3797    17.990790
# 3798    17.989451
# 3799    17.985461
# 3800    17.985205
# 3801    17.987434
# dtype: float64

# %%
## Actual prices (Out of sample)
actual_prices= arima_test
actual_prices
# Out:
# 3797    18.00
# 3798    17.95
# 3799    17.85
# 3800    17.75
# 3801    17.80
# 3802    17.70
# 3803    17.60
# 3804    17.55
# 3805    17.75
# 3806    17.75
# 3807    17.85
# 3808    17.90
# 3809    18.00
# 3810    18.30
# 3811    18.50
# Name: Close, dtype: float64

# %%
len(prices) *0.2
# Out:
# 762.4000000000001

# %% [markdown]
# Interestingly, ARIMA is able to capture the stock price trend.

# %%
## Plotting the ARIMA predictions
plt.figure(figsize= (15,8))

plt.plot(prices, label= 'Actual Price', linestyle= '--', marker= 'o')
plt.plot(autoARIMA_pred, label= 'Predicted Prices', linestyle= '--', marker= 'o')
plt.plot(autoARIMA_forecast, label= 'In Sample Predictions', linestyle= '--', marker= 'o')

plt.axvline(x= prices.index[-n], linestyle= '--', color= 'red')
plt.xlim(prices.index[-n-10], prices.index[-1])


plt.legend()
plt.grid()

# %%
## Predicted prices dataset
arima_predictions= pd.concat([autoARIMA_pred.reset_index(), actual_prices.reset_index()], axis= 'columns')
arima_predictions= arima_predictions.reset_index().drop(columns= ['index', 'level_0'])
arima_predictions.rename(columns={0: 'Predicted', ' Close': 'Actual'}, inplace=True)
arima_predictions['Residuals']= arima_predictions['Close']-arima_predictions['Predicted'] # Out of sample ARIMA residuals
arima_predictions
# Out:
#     Predicted  Close  Residuals
# 0   17.990790  18.00   0.009210
# 1   17.989451  17.95  -0.039451
# 2   17.985461  17.85  -0.135461
# 3   17.985205  17.75  -0.235205
# 4   17.987434  17.80  -0.187434
# 5   17.990543  17.70  -0.290543
# 6   17.994124  17.60  -0.394124
# 7   17.997874  17.55  -0.447874
# 8   18.001604  17.75  -0.251604
# 9   18.005264  17.75  -0.255264
# 10  18.008858  17.85  -0.158858
# 11  18.012403  17.90  -0.112403
# 12  18.015918  18.00  -0.015918
# 13  18.019419  18.30   0.280581
# 14  18.022914  18.50   0.477086

# %%
# Compute metrics
mse = mean_squared_error(arima_predictions['Close'], arima_predictions['Predicted'])
rmse = root_mean_squared_error(arima_predictions['Close'], arima_predictions['Predicted'])
mae = mean_absolute_error(arima_predictions['Close'], arima_predictions['Predicted'])
mape = mean_absolute_percentage_error(arima_predictions['Close'], arima_predictions['Predicted'])
r2 = r2_score(arima_predictions['Close'], arima_predictions['Predicted'])

# Print results
print(f"MSE: {mse}")
print(f"RMSE: {rmse}")
print(f"MAE: {mae}")
print(f"MAPE: {mape}")
print(f'r2:', r2)
# Out:
# MSE: 0.06824725315748448
# RMSE: 0.261241752324326
# MAE: 0.21940113864979124
# MAPE: 0.012276510324487264
# r2: -0.172185645834658

# %%
# We want to feed in sample predictions into the LSTM model
# residuals= pd.concat([autoARIMA.arima_res_.resid, arima_predictions['Residuals']], axis= 'rows')
in_sample_residuals= autoARIMA.arima_res_.resid
in_sample_residuals
# Out:
# 0       4.546501
# 1       0.046501
# 2       0.186992
# 3       0.106819
# 4       0.029990
#           ...
# 3792   -0.770618
# 3793    0.441996
# 3794    0.108950
# 3795    0.056307
# 3796   -0.086747
# Length: 3797, dtype: float64

# %%
full_residuals= pd.concat([in_sample_residuals, arima_predictions['Residuals']], axis= 'rows')
full_residuals.reset_index(drop= True, inplace= True)
full_residuals.tail(15)
# Out:
# 3797    0.009210
# 3798   -0.039451
# 3799   -0.135461
# 3800   -0.235205
# 3801   -0.187434
# 3802   -0.290543
# 3803   -0.394124
# 3804   -0.447874
# 3805   -0.251604
# 3806   -0.255264
# 3807   -0.158858
# 3808   -0.112403
# 3809   -0.015918
# 3810    0.280581
# 3811    0.477086
# dtype: float64

# %%
full_arima_prices= pd.concat([autoARIMA_forecast, autoARIMA_pred], axis= 'rows')
full_arima_prices.reset_index(drop= True, inplace= True)
full_arima_prices.tail(15)
# Out:
# 3797    17.990790
# 3798    17.989451
# 3799    17.985461
# 3800    17.985205
# 3801    17.987434
# 3802    17.990543
# 3803    17.994124
# 3804    17.997874
# 3805    18.001604
# 3806    18.005264
# 3807    18.008858
# 3808    18.012403
# 3809    18.015918
# 3810    18.019419
# 3811    18.022914
# dtype: float64

# %%
lstm_data= pd.DataFrame(pd.concat([full_arima_prices, prices], axis='columns'))
lstm_data.rename(columns={0: 'ARIMA_Prices'}, inplace= True)
lstm_data[['Open', 'High', 'Low', 'Volume']]= data[['Open', 'High', 'Low', 'Volume']]
lstm_data.drop(columns= 'ARIMA_Prices', inplace= True)
lstm_data
# Out:
#       Close   Open   High    Low    Volume
# 0      4.55   4.55   4.55   4.55   2802800
# 1      4.60   4.55   4.60   4.60   1965900
# 2      4.80   4.60   4.80   4.80   3856500
# 3      4.95   4.80   4.95   4.95  22382600
# 4      5.00   4.95   5.00   5.00  37595102
# ...     ...    ...    ...    ...       ...
# 3807  17.85  18.00  18.00  17.75   7973300
# 3808  17.90  17.90  18.10  17.80   7378100
# 3809  18.00  18.00  18.20  17.90   1445000
# 3810  18.30  18.15  18.45  18.00   9457500
# 3811  18.50  18.30  18.65  18.20  13410200
#
# [3812 rows x 5 columns]

# %% [markdown]
# Checking null values

# %%
lstm_data.isnull().sum()
# Out:
# Close     0
# Open      0
# High      0
# Low       0
# Volume    0
# dtype: int64

# %% [markdown]
# -------------------

# %% [markdown]
# # LSTM Prediction

# %% [markdown]
# #### Lagged Versions of Price

# %%
lagNames= ['Close (1)', 'Close (2)', 'Close (3)', 'Close (4)', 'Close (5)']
shifts= [-1,-2,-3,-4,-5]

for l,i in zip(lagNames ,shifts):
    lstm_data[l]= lstm_data['Close'].shift(i)

# %%
print(lstm_data.isnull().sum()) # 5 null values

lstm_data.dropna(inplace= True)
lstm_data.head()
 # Null values observed due to the lagging
# Out:
# Close        0
# Open         0
# High         0
# Low          0
# Volume       0
# Close (1)    1
# Close (2)    2
# Close (3)    3
# Close (4)    4
# Close (5)    5
# dtype: int64
#    Close  Open  High   Low    Volume  Close (1)  Close (2)  Close (3)  \
# 0   4.55  4.55  4.55  4.55   2802800       4.60       4.80       4.95
# 1   4.60  4.55  4.60  4.60   1965900       4.80       4.95       5.00
# 2   4.80  4.60  4.80  4.80   3856500       4.95       5.00       5.05
# 3   4.95  4.80  4.95  4.95  22382600       5.00       5.05       5.15
# 4   5.00  4.95  5.00  5.00  37595102       5.05       5.15       5.40
#
#    Close (4)  Close (5)
# 0       5.00       5.05
# 1       5.05       5.15
# 2       5.15       5.40
# 3       5.40       5.75
# 4       5.75       5.55

# %% [markdown]
# ### Technical Indicator variables

# %%
## Moving Averages
lstm_data['SMA5'] = ta.sma(lstm_data['Close'], length=5)
lstm_data['SMA10'] = ta.sma(lstm_data['Close'], length=10)
lstm_data['SMA15'] = ta.sma(lstm_data['Close'], length=15)
lstm_data['SMA20'] = ta.sma(lstm_data['Close'], length=20)

lstm_data['EMA5'] = ta.ema(lstm_data['Close'], length=5)
lstm_data['EMA10'] = ta.ema(lstm_data['Close'], length=10)
lstm_data['EMA15'] = ta.ema(lstm_data['Close'], length=15)
lstm_data['EMA20'] = ta.ema(lstm_data['Close'], length=20)

lstm_data['TRIMA5'] = ta.trima(lstm_data['Close'], length=5)
lstm_data['TRIMA10'] = ta.trima(lstm_data['Close'], length=10)
lstm_data['TRIMA20'] = ta.trima(lstm_data['Close'], length=20)

lstm_data['KAMA10'] = ta.kama(lstm_data['Close'], length=10)
lstm_data['KAMA20'] = ta.kama(lstm_data['Close'], length=20)
lstm_data['KAMA30'] = ta.kama(lstm_data['Close'], length=30)

## MACD
macd= ta.macd(lstm_data['Close'])

# EMV (Ease of Movement) requires 'High', 'Low', 'Close', and 'Volume' columns
lstm_data['EMV']= ta.eom(high=lstm_data['High'], low=lstm_data['Low'], close=lstm_data['Close'], volume=lstm_data['Volume'])

# Directional Movement Index (DMI)
adx5 = ta.adx(lstm_data['High'], lstm_data['Low'], lstm_data['Close'], length=5)
adx5.columns = ['ADX5', 'DMP5', 'DMN5']
lstm_data = lstm_data.join(adx5)

adx10 = ta.adx(lstm_data['High'], lstm_data['Low'], lstm_data['Close'], length=10)
adx10.columns = ['ADX10', 'DMP10', 'DMN10']
lstm_data = lstm_data.join(adx10)

adx20 = ta.adx(lstm_data['High'], lstm_data['Low'], lstm_data['Close'], length=20)
adx20.columns = ['ADX20', 'DMP20', 'DMN20']
lstm_data = lstm_data.join(adx20)

# Stochastic Oscillator (KDJ)
stoch = ta.stoch(lstm_data['High'], lstm_data['Low'], lstm_data['Close'], k=14, d=3, smooth_k=3)
stoch.columns = ['STOCHk', 'STOCHd']
lstm_data = lstm_data.join(stoch)

# Relative Strength Index (RSI)
lstm_data['RSI14'] = ta.rsi(lstm_data['Close'], length=14)
lstm_data['RSI8'] = ta.rsi(lstm_data['Close'], length=8)

# Rate of Change
lstm_data['ROC']= ta.roc(lstm_data['Close'])

# Percentage Volume Oscillator (PVO)
pvo= ta.pvo(lstm_data['Volume'])

# On-Balance Volume (OBV)
lstm_data['OBV']= ta.obv(lstm_data['Close'],lstm_data['Volume'])

# Bolinger Bands (BOLL)
bbands = ta.bbands(lstm_data['Close'], length=20)
bbands.columns = ['BBL_20', 'BBM_20', 'BBU_20', 'BBB_20', 'BBP_20']
lstm_data = lstm_data.join(bbands)

# MACD
macd_510 = ta.macd(lstm_data['Close'], fast=5, slow=10)
macd_510.columns = ["MACD510", "MACD510_hist", "MACD510_signal"]
lstm_data = lstm_data.join(macd_510)

macd_520 = ta.macd(lstm_data['Close'], fast=5, slow=20)
macd_520.columns = ["MACD520", "MACD520_hist", "MACD520_signal"]
lstm_data = lstm_data.join(macd_520)

macd_1020 = ta.macd(lstm_data['Close'], fast=10, slow=20)
macd_1020.columns = ["MACD1020", "MACD1020_hist", "MACD1020_signal"]
lstm_data = lstm_data.join(macd_1020)

macd_1520 = ta.macd(lstm_data['Close'], fast=15, slow=20)
macd_1520.columns = ["MACD1520", "MACD1520_hist", "MACD1520_signal"]
lstm_data = lstm_data.join(macd_1520)

macd_1226 = ta.macd(lstm_data['Close'], fast=12, slow=26)
macd_1226.columns = ["MACD1226", "MACD1226_hist", "MACD1226_signal"]
lstm_data = lstm_data.join(macd_1226)

## Momentum
lstm_data['MOM10'] = ta.mom(lstm_data['Close'], length=10)
lstm_data['MOM15'] = ta.mom(lstm_data['Close'], length=15)
lstm_data['MOM20'] = ta.mom(lstm_data['Close'], length=20)

lstm_data['ROC5'] = ta.roc(lstm_data['Close'], length=5)
lstm_data['ROC10'] = ta.roc(lstm_data['Close'], length=10)
lstm_data['ROC20'] = ta.roc(lstm_data['Close'], length=20)

# PPO
ppo = ta.ppo(lstm_data['Close'])
ppo.columns = ['PPO', 'PPO_hist', 'PPO_signal']
lstm_data = lstm_data.join(ppo)

# ATR
lstm_data['ATR'] = ta.atr(lstm_data['High'], lstm_data['Low'], lstm_data['Close'], length=14)

# Ultimate Oscillator
lstm_data['ULTOSC'] = ta.uo(lstm_data['High'], lstm_data['Low'], lstm_data['Close'])

# Williams %R
lstm_data['WILLR'] = ta.willr(lstm_data['High'], lstm_data['Low'], lstm_data['Close'])

# True Range
lstm_data['TRange'] = lstm_data['High'] - lstm_data['Low']

# Typical Price
lstm_data['TYPPRICE'] = (lstm_data['High'] + lstm_data['Low'] + lstm_data['Close']) / 3

lstm_data.dropna(inplace=True)
lstm_data.reset_index(drop= True, inplace= True)



# ## Simple moving average (Fast, Slow)
# lstm_data['SMA Close (F)'] = ta.sma(lstm_data["Close"], length=10)
# lstm_data['SMA Close (M)'] = ta.sma(lstm_data['Close'], length=50)

# ## Exponential Moving Average (Fast, Slow)
# lstm_data['EMA Close (F)'] = ta.ema(lstm_data["Close"], length=10)
# lstm_data['EMA Close (M)'] = ta.ema(lstm_data['Close'], length=50)

# ## Double Exponential Moving Average (Fast, Slow)
# lstm_data['DEMA Close (F)'] = ta.dema(lstm_data["Close"], length=10)
# lstm_data['DEMA Close (M)'] = ta.dema(lstm_data['Close'], length=50)

# ## MACD
# macdClose = ta.macd(lstm_data['Close'])

# ## Bollinger Bands
# bbandsClose = ta.bbands(lstm_data['Close'])

# ## Money Flow Index
# ta.mfi(lstm_data['High'], lstm_data['Low'], lstm_data['Close'], lstm_data['Volume'])

# ## Momentum
# lstm_data['Momentum Close'] = ta.mom(lstm_data['Close'])

# ## Relative Strength Index
# lstm_data['RSI Close'] = ta.rsi(lstm_data['Close'], period=14)

# ## True Range
# lstm_data['TrueRange'] = ta.true_range(lstm_data['High'], lstm_data['Low'], lstm_data['Close'])

# ## Average True Range
# lstm_data['AvgTrueRange'] = ta.atr(lstm_data['High'], lstm_data['Low'], lstm_data['Close'])

# ## Bias
# lstm_data['Bias Close'] = ta.bias(lstm_data['Close'], length=10)

# ## Ensure lstm_data has a DatetimeIndex for VWAP calculation
# if not isinstance(lstm_data.index, pd.DatetimeIndex):
# 	# Use the Date column from the original data DataFrame
# 	lstm_data = lstm_data.copy()
# 	lstm_data.index = data.loc[lstm_data.index, 'Date']

# ## VWAP (Volume Weighted Average Price)
# lstm_data['VWAP'] = ta.vwap(lstm_data['High'], lstm_data['Low'], lstm_data['Close'], lstm_data['Volume'])

# %%
lstm_data
# Out:
#       Close   Open   High    Low    Volume  Close (1)  Close (2)  Close (3)  \
# 0      5.40   5.40   5.40   5.40  17827301       5.35       5.40       5.40
# 1      5.35   5.40   5.35   5.35   9327800       5.40       5.40       5.40
# 2      5.40   5.35   5.40   5.40  10131400       5.40       5.40       5.40
# 3      5.40   5.40   5.40   5.40   9291900       5.40       5.40       5.40
# 4      5.40   5.40   5.40   5.40   6371900       5.40       5.40       5.40
# ...     ...    ...    ...    ...       ...        ...        ...        ...
# 3760  17.70  17.75  17.90  17.50  12208600      17.60      17.55      17.75
# 3761  17.60  17.70  17.85  17.45    468400      17.55      17.75      17.75
# 3762  17.55  17.60  17.80  17.45    355700      17.75      17.75      17.85
# 3763  17.75  17.80  18.00  17.55   3201300      17.75      17.85      17.90
# 3764  17.75  17.65  17.80  17.65   1825700      17.85      17.90      18.00
#
#       Close (4)  Close (5)  ...     ROC10     ROC20       PPO  PPO_hist  \
# 0          5.40       5.40  ...  0.934579  2.857143 -0.981092 -0.089872
# 1          5.40       5.40  ...  0.000000  2.884615 -0.910389 -0.015336
# 2          5.40       5.40  ...  1.886792  8.000000 -0.726710  0.134675
# 3          5.40       5.45  ...  3.846154  0.934579 -0.542636  0.254999
# 4          5.45       5.45  ...  1.886792 -5.263158 -0.280564  0.413657
# ...         ...        ...  ...       ...       ...       ...       ...
# 3760      17.75      17.85  ...  1.724138 -5.347594 -1.431504 -0.656473
# 3761      17.85      17.90  ... -0.564972 -7.124011 -1.630204 -0.684139
# 3762      17.90      18.00  ... -2.228412 -6.896552 -1.529799 -0.466987
# 3763      18.00      18.30  ... -1.662050 -5.585106 -1.464909 -0.321678
# 3764      18.30      18.50  ... -1.388889 -5.080214 -1.483727 -0.272396
#
#       PPO_signal       ATR     ULTOSC      WILLR  TRange   TYPPRICE
# 0      -0.891220  0.074535  74.231806 -33.333333    0.00   5.400000
# 1      -0.895054  0.072687  54.867827 -25.000000    0.00   5.350000
# 2      -0.861385  0.070985  59.523810   0.000000    0.00   5.400000
# 3      -0.797635  0.065679  60.944998   0.000000    0.00   5.400000
# 4      -0.694221  0.060785  60.588463   0.000000    0.00   5.400000
# ...          ...       ...        ...        ...     ...        ...
# 3760   -0.775031  0.501841  47.631688 -55.172414    0.40  17.700000
# 3761   -0.946065  0.494567  45.511484 -62.068966    0.40  17.633333
# 3762   -1.062812  0.484241  43.073818 -65.517241    0.35  17.600000
# 3763   -1.143232  0.481795  45.119409 -51.724138    0.45  17.766667
# 3764   -1.211331  0.458095  43.490695 -71.428571    0.15  17.733333
#
# [3765 rows x 74 columns]

# %%
lstm_data.isnull().sum()
# Out:
# Close       0
# Open        0
# High        0
# Low         0
# Volume      0
#            ..
# ATR         0
# ULTOSC      0
# WILLR       0
# TRange      0
# TYPPRICE    0
# Length: 74, dtype: int64

# %% [markdown]
# Replacing inf values with zero as inf was obtained by dividing by zero in the technical indicator columns.

# %% [markdown]
# ### Data Splitting

# %% [markdown]
# First step before any transformation, feature selection, etc is to split the data into training and testing sets in order to avoid data leakage from the training set to the testing set. The testing set represents data we have not seen before so it should remain completely untouched. We apply an 80-20 ratio

# %%
split= int(len(lstm_data) * 0.8) 
train, test= lstm_data[:split], lstm_data[split:]
# Split the data sequentially as we are dealing with time series

test
# Out:
#       Close   Open   High    Low    Volume  Close (1)  Close (2)  Close (3)  \
# 3012  35.10  36.05  36.05  34.90   5545700      35.05      35.50      35.50
# 3013  35.05  35.10  35.50  34.80   9826100      35.50      35.50      35.65
# 3014  35.50  35.20  36.00  35.20   1807600      35.50      35.65      35.40
# 3015  35.50  35.60  35.60  35.30   2714200      35.65      35.40      34.95
# 3016  35.65  35.60  36.80  35.30   3006700      35.40      34.95      34.50
# ...     ...    ...    ...    ...       ...        ...        ...        ...
# 3760  17.70  17.75  17.90  17.50  12208600      17.60      17.55      17.75
# 3761  17.60  17.70  17.85  17.45    468400      17.55      17.75      17.75
# 3762  17.55  17.60  17.80  17.45    355700      17.75      17.75      17.85
# 3763  17.75  17.80  18.00  17.55   3201300      17.75      17.85      17.90
# 3764  17.75  17.65  17.80  17.65   1825700      17.85      17.90      18.00
#
#       Close (4)  Close (5)  ...     ROC10     ROC20       PPO  PPO_hist  \
# 3012      35.65      35.40  ... -4.098361 -8.355091 -2.417303 -1.155014
# 3013      35.40      34.95  ...  1.447178 -9.431525 -2.787402 -1.220091
# 3014      34.95      34.50  ... -0.420757 -7.792208 -2.802689 -0.988302
# 3015      34.50      35.50  ... -1.251739 -6.824147 -2.336157 -0.417416
# 3016      35.50      36.15  ... -1.383126 -4.551539 -2.091909 -0.138534
# ...         ...        ...  ...       ...       ...       ...       ...
# 3760      17.75      17.85  ...  1.724138 -5.347594 -1.431504 -0.656473
# 3761      17.85      17.90  ... -0.564972 -7.124011 -1.630204 -0.684139
# 3762      17.90      18.00  ... -2.228412 -6.896552 -1.529799 -0.466987
# 3763      18.00      18.30  ... -1.662050 -5.585106 -1.464909 -0.321678
# 3764      18.30      18.50  ... -1.388889 -5.080214 -1.483727 -0.272396
#
#       PPO_signal       ATR     ULTOSC      WILLR  TRange   TYPPRICE
# 3012   -1.262288  1.135925  44.895985 -73.750000    1.15  35.350000
# 3013   -1.567311  1.104788  44.430332 -75.000000    0.70  35.116667
# 3014   -1.814387  1.093731  42.652326 -63.750000    0.80  35.566667
# 3015   -1.918741  1.037036  41.245913 -61.333333    0.30  35.466667
# 3016   -1.953374  1.070105  38.885936 -56.756757    1.50  35.916667
# ...          ...       ...        ...        ...     ...        ...
# 3760   -0.775031  0.501841  47.631688 -55.172414    0.40  17.700000
# 3761   -0.946065  0.494567  45.511484 -62.068966    0.40  17.633333
# 3762   -1.062812  0.484241  43.073818 -65.517241    0.35  17.600000
# 3763   -1.143232  0.481795  45.119409 -51.724138    0.45  17.766667
# 3764   -1.211331  0.458095  43.490695 -71.428571    0.15  17.733333
#
# [753 rows x 74 columns]

# %% [markdown]
# ### Data Transformation
# As the variables are differently scaled, we use MinMax transformation to scale the variables between 0 and 1. We transform the training dataset and testing dataset separately to avoid data leakage
#
# We also transform the input features and target variable sepetrately to avoid differing values from the original during `inverse_transform` later on.

# %%
## Scalers
feature_scaler = MinMaxScaler(feature_range=(0,1)) # Scales the input feature
target_scaler = MinMaxScaler(feature_range=(0,1)) # Scales the target feature

## Scale the training and testing data separately to avoid data leakage
# Training Target feature dataset
target_scaled_train = target_scaler.fit_transform(train['Close'].values.reshape(-1, 1))
target_scaled_train_df = pd.DataFrame(target_scaled_train, columns=['Close'])

# Testing Target feeature dataset (No need to scale target testing data)
target_test_data= test['Close'].values
target_test_data_df = pd.DataFrame(target_test_data, columns=['Close'])


# Training Input feature dataset
train_features = train.drop(columns='Close')
train_scaled = feature_scaler.fit_transform(train_features)
train_scaled_df = pd.DataFrame(train_scaled, columns=train_features.columns)
# Add back the target feature (we do this to prevent dealing with multiple variables)
train_scaled_df['Close'] = target_scaled_train_df['Close'].values

# Testing Input feature dataset
test_features = test.drop(columns='Close')
test_scaled = feature_scaler.transform(test_features)
test_scaled_df = pd.DataFrame(test_scaled, columns=test_features.columns)
# Add back the target feature
test_scaled_df['Close'] = target_test_data_df['Close'].values

# The two important variables we will use going further are 'train_scaled_df' and 'test_scaled_df'
test_scaled_df.head()
# Out:
#        Open      High       Low    Volume  Close (1)  Close (2)  Close (3)  \
# 0  0.788166  0.783274  0.779661  0.036079   0.765403   0.776066   0.776066
# 1  0.765680  0.770318  0.777240  0.064452   0.776066   0.776066   0.779621
# 2  0.768047  0.782097  0.786925  0.011300   0.776066   0.779621   0.773697
# 3  0.777515  0.772674  0.789346  0.017310   0.779621   0.773697   0.763033
# 4  0.777515  0.800942  0.789346  0.019249   0.773697   0.763033   0.752370
#
#    Close (4)  Close (5)      SMA5  ...     ROC20       PPO  PPO_hist  \
# 0   0.779621   0.773697  0.806444  ...  0.299871  0.418445  0.281438
# 1   0.773697   0.763033  0.794749  ...  0.275224  0.394105  0.271585
# 2   0.763033   0.752370  0.785203  ...  0.312759  0.393100  0.306679
# 3   0.752370   0.776066  0.779475  ...  0.334925  0.423781  0.393113
# 4   0.776066   0.791469  0.777566  ...  0.386961  0.439844  0.435337
#
#    PPO_signal       ATR    ULTOSC     WILLR    TRange  TYPPRICE  Close
# 0    0.479075  0.804761  0.429487  0.262500  0.383333  0.776410  35.10
# 1    0.455446  0.782259  0.424137  0.250000  0.233333  0.770850  35.05
# 2    0.436307  0.774269  0.403711  0.362500  0.266667  0.781573  35.50
# 3    0.428223  0.733298  0.387555  0.386667  0.100000  0.779190  35.50
# 4    0.425540  0.757195  0.360443  0.432432  0.500000  0.789913  35.65
#
# [5 rows x 74 columns]

# %% [markdown]
# ### Feature Selection
# First, we check the correlation heatmap between the features and the target variable (Close Price). Then we perform further feature selection via Recursive Feature Elimination (RFE) using XGBoost.
#
# Recursive Feature Elimination works by recursively removing features that do not improve model performance. We select the best number of features that produce the lowest loss (MSE).

# %%
lstm_data.columns
# Out:
# Index(['Close', 'Open', 'High', 'Low', 'Volume', 'Close (1)', 'Close (2)',
#        'Close (3)', 'Close (4)', 'Close (5)', 'SMA5', 'SMA10', 'SMA15',
#        'SMA20', 'EMA5', 'EMA10', 'EMA15', 'EMA20', 'TRIMA5', 'TRIMA10',
#        'TRIMA20', 'KAMA10', 'KAMA20', 'KAMA30', 'EMV', 'ADX5', 'DMP5', 'DMN5',
#        'ADX10', 'DMP10', 'DMN10', 'ADX20', 'DMP20', 'DMN20', 'STOCHk',
#        'STOCHd', 'RSI14', 'RSI8', 'ROC', 'OBV', 'BBL_20', 'BBM_20', 'BBU_20',
#        'BBB_20', 'BBP_20', 'MACD510', 'MACD510_hist', 'MACD510_signal',
#        'MACD520', 'MACD520_hist', 'MACD520_signal', 'MACD1020',
#        'MACD1020_hist', 'MACD1020_signal', 'MACD1520', 'MACD1520_hist',
#        'MACD1520_signal', 'MACD1226', 'MACD1226_hist', 'MACD1226_signal',
#        'MOM10', 'MOM15', 'MOM20', 'ROC5', 'ROC10', 'ROC20', 'PPO', 'PPO_hist',
#        'PPO_signal', 'ATR', 'ULTOSC', 'WILLR', 'TRange', 'TYPPRICE'],
#       dtype='object')

# %%
corr_matrix = lstm_data.corr()

# Plot heatmap of all features correlated with Close price
plt.figure(figsize=(8, len(corr_matrix)-1))
sns.heatmap(
    corr_matrix[['Close']].sort_values(by='Close', ascending=False),
    annot=True, cmap='coolwarm', vmin=-1, vmax=1
)
plt.title('Correlation of Features with Close Price')

# Print variables with correlation >= 0.99 (excluding 'Close' itself)
high_corr = corr_matrix['Close'].drop('Close').abs()
high_corr_vars = high_corr[high_corr >= 0.99]
correlated_variables= list(high_corr_vars.index)
print("Variables with correlation >= 0.99 to 'Close':", correlated_variables)
print("No. of highly correlated variables:", len(correlated_variables))
# Out:
# Variables with correlation >= 0.99 to 'Close': ['Open', 'High', 'Low', 'Close (1)', 'Close (2)', 'Close (3)', 'Close (4)', 'Close (5)', 'SMA5', 'SMA10', 'SMA15', 'SMA20', 'EMA5', 'EMA10', 'EMA15', 'EMA20', 'TRIMA5', 'TRIMA10', 'TRIMA20', 'KAMA10', 'KAMA20', 'KAMA30', 'BBL_20', 'BBM_20', 'BBU_20', 'TYPPRICE']
# No. of highly correlated variables: 26

# %% [markdown]
# The below code for RFE is divided into two blocks.
# - Block 1 is for finding the best number of features. RFE is ran multiple times per n number of features and the MSE is recorded for each run. The best number of features is the one that produces the lowest MSE.
# - Block 2 is for running the best number of features which proceed to the next stage.
#
# In the below code for RFE, first run `#### Block 1 #####` with `#### Block 2 #####` commented out to find the best number of features. Then uncomment #### Block 2 ##### whie commenting out `#### Block 1 #####` and run `#### Block 2 #####` to get the results for the best number of features.

# %%
## Data preparation for RFE
X_rfe= train_scaled_df[correlated_variables] # variables highly correlated with Close price (>0.99)
y_rfe= train_scaled_df['Close'] # Target variable

## Data splitting for RFE 
## We use only the training dataset for feature selection to avoid data leakage
rfe_split= int(len(train_scaled_df) * 0.2) 
xr_train, xr_test= X_rfe[:rfe_split], X_rfe[rfe_split:]
yr_train, yr_test= y_rfe[:rfe_split], y_rfe[rfe_split:]

## We define an XGBoost regression function to check the accuracy of the model with the selected features
def run_XG(xr_train, xr_test, yr_train, yr_test):
    regr= XGBRegressor(objective= 'reg:squarederror', # objective is to minimize mean squared error
                       n_estimators= 500, # 500 decision trees
                       learning_rate= 0.1, 
                       random_state= 42)
    regr.fit(xr_train, yr_train)
    yr_pred= regr.predict(xr_test)
    print('MSE Loss:', mean_squared_error(yr_test, yr_pred))



# ### Block 1 #####

# ## For determining the optimum number of features
# results = []
# for features in range(2, len(X_rfe.columns)+1):
#     rfe = RFE(XGBRegressor(objective='reg:squarederror', n_estimators=500, random_state=42), n_features_to_select=features)
#     rfe.fit(xr_train, yr_train)
#     xr1_train = rfe.transform(xr_train)
#     xr1_test = rfe.transform(xr_test)
#     regr = XGBRegressor(objective='reg:squarederror', n_estimators=500, learning_rate=0.1, random_state=42)
#     regr.fit(xr1_train, yr_train)
#     yr_pred = regr.predict(xr1_test)
#     mse_loss = mean_squared_error(yr_test, yr_pred)
#     print(features)
#     print('MSE Loss:', mse_loss)
#     print()
#     results.append({'num_features': features, 'mse_loss': mse_loss})

# # Save results to CSV
# rfe_results = pd.DataFrame(results)
# rfe_results.to_csv('rfe_results_standalone_lstm.csv', index=False)



#### Block 2 #####

## After finding the best no of features
features= 9
rfe = RFE(XGBRegressor(objective='reg:squarederror', n_estimators=500, random_state=42), n_features_to_select=features, verbose= 1)
rfe.fit(xr_train, yr_train)
xr1_train = rfe.transform(xr_train)
xr1_test = rfe.transform(xr_test)
print(features)
run_XG(xr1_train, xr1_test, yr_train, yr_test)
print()
# Out:
# Fitting estimator with 26 features.
# Fitting estimator with 25 features.
# Fitting estimator with 24 features.
# Fitting estimator with 23 features.
# Fitting estimator with 22 features.
# Fitting estimator with 21 features.
# Fitting estimator with 20 features.
# Fitting estimator with 19 features.
# Fitting estimator with 18 features.
# Fitting estimator with 17 features.
# Fitting estimator with 16 features.
# Fitting estimator with 15 features.
# Fitting estimator with 14 features.
# Fitting estimator with 13 features.
# Fitting estimator with 12 features.
# Fitting estimator with 11 features.
# Fitting estimator with 10 features.
# 9
# MSE Loss: 0.19923742598185226

# %%
gc.collect()
# Out:
# 19243

# %% [markdown]
# We find 9 features produce the lowest MSE loss for predicting Close Price

# %%
## Selected Features
selected= np.where(rfe.support_== True)
print(selected)

for i in selected:
    print(xr_train.columns[i])
print()
print('Number of features selected:', len(selected[0]))
# Out:
# (array([ 0,  1,  2,  4,  7, 12, 17, 19, 25], dtype=int64),)
# Index(['Open', 'High', 'Low', 'Close (2)', 'Close (5)', 'EMA5', 'TRIMA10',
#        'KAMA10', 'TYPPRICE'],
#       dtype='object')
#
# Number of features selected: 9

# %%
## Target Variable data
train_target = train_scaled_df['Close'] # (y_train)
test_target=  test_scaled_df['Close']  # (y_test)


## Input variable data
selected= ['Open', 'High', 'Low', 'Close (2)', 'Close (5)', 'EMA5', 'TRIMA10',
       'KAMA10', 'TYPPRICE']


train_scaled_df= train_scaled_df[selected]
test_scaled_df= test_scaled_df[selected]

print('x_train:', train_scaled_df.shape)
print('y_train:', test_scaled_df.shape)

print('x_test:', train_target.shape)
print('y_test:', test_target.shape)
# Out:
# x_train: (3012, 9)
# y_train: (753, 9)
# x_test: (3012,)
# y_test: (753,)

# %% [markdown]
# Where column `Close` is the target variable to be predicted.

# %% [markdown]
# ### LSTM Data Preparation
# We create a time series model for LSTM by creating sequences of data. Each sequence will consist of a certain number of previous time steps (lookback period) to predict the next time step.
#
# The input variable dataset will be structured in a 3D array consisting of (Number of samples, Time steps, Number of features). The number of time steps is the lookback period we choose.
#
# The target variable will be a 2D array consisting of (Number of samples, Number of output features- 1 feature).

# %%
## Convert the above data to pandas arrays (2D arrays)
# (n_samples, features)
train_variables= train_scaled_df.values 
test_variables= test_scaled_df.values

# (n_samples, target feature)
train_output= train_target.values.reshape(-1,1)
test_output= test_target.values.reshape(-1,1)

# %%
train_variables.shape
# Out:
# (3012, 9)

# %% [markdown]
# We define a lookback window function that creates sequences of data based on the lookback period.

# %%
## Sequencing data function
def sequences(input_data, target_feature_data, lookback_days):
    X, y = [], []
    for i in range(lookback_days, len(input_data)):
        X.append(input_data[i-lookback_days:i, :])
        y.append(target_feature_data[i])
    return np.array(X), np.array(y)

## Generate sequences for train/test sets
days = 24
x_train, y_train = sequences(train_variables, train_output, days)
x_test, y_test = sequences(test_variables, test_output, days)

## Verify data shapes
print('x_train Shape:', np.shape(x_train))
print('x_train Dimensions:', x_train.ndim)
print()
print('x_test Shape:', np.shape(x_test))
print('x_test Dimensions:', x_test.ndim)
print()
print('y_train Shape:', np.shape(y_train))
print('y_train Dimensions:', y_train.ndim)
print()
print('y_test Shape:', np.shape(y_test))
print('y_test Dimensions:', y_test.ndim)
# Out:
# x_train Shape: (2988, 24, 9)
# x_train Dimensions: 3
#
# x_test Shape: (729, 24, 9)
# x_test Dimensions: 3
#
# y_train Shape: (2988, 1)
# y_train Dimensions: 2
#
# y_test Shape: (729, 1)
# y_test Dimensions: 2

# %% [markdown]
# ### The LSTM Model
# ##### Hyperparameter Tuning
# Here we find the best hyperparameters for the LSTM model using a random search approach.
#
# Uncomment the below code to run the hyperparameter tuner. It will take a while to run as it runs multiple iterations of the LSTM model with different hyperparameters.

# %%
# ## Define the model-building function
# def build_model(hp):
#     model = Sequential()

#     dropout_rate = hp.Float('dropout_rate', 0.1, 0.4, step=0.1)

#     num_layers = hp.Int('layers', 2, 3)  # Number of LSTM layers

#     for i in range(num_layers):
#         units = hp.Int('units_' + str(i), min_value=10, max_value=100, step=10) # No of units
#         return_seq = True if i < num_layers - 1 else False  # Only last layer gets False
    
#         if i == 0:
#             model.add(LSTM(units=units,
#                        return_sequences=return_seq,
#                        input_shape=(x_train.shape[1], x_train.shape[2])))
#         else:
#             model.add(LSTM(units=units,
#                        return_sequences=return_seq))
    
#         model.add(Dropout(dropout_rate))  # Dropout after each LSTM layer

#     ## Output layer
#     model.add(Dense(units=1, 
#                     activation=hp.Choice('act_1', ['relu', 'sigmoid', 'linear']))) # Choose activation function
                    

#     # Compile the model
#     model.compile(keras.optimizers.Adam(learning_rate= 0.00005), loss= 'mean_squared_error')
#     return model


# # Initialize the tuner
# tuner = keras_tuner.RandomSearch(build_model,
#     objective='val_loss',  # Use validation loss as the optimization metric
#     max_trials=4,  # Number of hyperparameter configurations to try
#     executions_per_trial=2,  # Average results across multiple runs
#     directory='safaricom_final_model2',  # Directory to save tuning results
#     project_name='lstm_standalone_final2')

# tuner.search_space_summary()

# ## Callbacks
# es= EarlyStopping(monitor= 'val_loss', min_delta= 1e-6, patience= 20, verbose= 1)
# rlr= ReduceLROnPlateau(monitor= 'val_loss', factor= 0.5, patience= 20, verbose= 1)

# # Perform the hyperparameter search
# tuner.search(x_train, y_train,
#             epochs=2000,  # Number of epochs for each trial
#             batch_size=32,  # Batch size
#             validation_split= 0.2,  # Validation data (We dont use the x_test, y_test; those are only used in the final evaluation)
#             callbacks= [es, rlr]
# )

# # Display the results of the hyperparameter search
# tuner.results_summary()

# # Retrieve the best hyperparameters and model
# best_hps = tuner.get_best_hyperparameters(num_trials=1)[0]
# best_model = tuner.get_best_models(num_models=1)[0]

# # Train the best model with the optimal hyperparameters
# history = best_model.fit(
#     x_train,
#     y_train,
#     epochs=2000,  # Further training with optimal hyperparameters
#     batch_size=32,
#     validation_split= 0.2,callbacks= [es, rlr])

# # Save the best model
# best_model.save('lstm_standalone_final2.keras')

# %%
best_hps.values
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[39], line 1
# ----> 1 best_hps.values
#
# NameError: name 'best_hps' is not defined

# %%
best_model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ lstm (LSTM)                     │ (None, 24, 30)         │         4,800 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 24, 30)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_1 (LSTM)                   │ (None, 60)             │        21,840 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 60)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 1)              │            61 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 80,105 (312.91 KB)
#  Trainable params: 26,701 (104.30 KB)
#  Non-trainable params: 0 (0.00 B)
#  Optimizer params: 53,404 (208.61 KB)

# %% [markdown]
# Here we construct the LSTM model with the best hyperparameters found in the previous step.

# %%
## 
model= Sequential()
model.add(LSTM(units= 30, return_sequences= True, input_shape= (x_train.shape[1], x_train.shape[2])))
model.add(Dropout(0.1)) 
# # Higher droupout rates means the the model is discarding more irrelevant info that has little/no effect training
# model.add(LSTM(units= 40, return_sequences= True, input_shape= (x_train.shape[1], x_train.shape[2])))
# model.add(Dropout(0.3))
# # model.add(LSTM(units= 80, return_sequences= True, input_shape= (x_train.shape[1], x_train.shape[2])))
# # model.add(Dropout(0.1))
model.add(LSTM(units= 60, input_shape= (x_train.shape[1], x_train.shape[2])))
model.add(Dropout(0.1))
model.add(Dense(units= 1, activation= 'relu'))

## Callbacks
es= EarlyStopping(monitor= 'loss', min_delta= 1e-6, patience= 20, verbose= 1)
rlr= ReduceLROnPlateau(monitor= 'val_loss', factor= 0.5, patience= 20, verbose= 1)

## Compiling & Fitting
model.compile(keras.optimizers.Adam(learning_rate= 0.00005), loss= 'mean_squared_error')
model.fit(x_train, y_train, epochs= 2000, batch_size= 32, callbacks= [es, rlr], validation_split= 0.2, shuffle= True)
# Out:
# Epoch 1/2000
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 7s 21ms/step - loss: 0.0862 - val_loss: 0.0557 - learning_rate: 5.0000e-05
# Epoch 2/2000
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - loss: 0.0039 - val_loss: 0.0165 - learning_rate: 5.0000e-05
# Epoch 3/2000
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 3s 36ms/step - loss: 0.0024 - val_loss: 0.0108 - learning_rate: 5.0000e-05
# Epoch 4/2000
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 3s 36ms/step - loss: 0.0020 - val_loss: 0.0076 - learning_rate: 5.0000e-05
# Epoch 5/2000
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 3s 36ms/step - loss: 0.0018 - val_loss: 0.0048 - learning_rate: 5.0000e-05
# Epoch 6/2000
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 2s 23ms/step - loss: 0.0016 - val_loss: 0.0061 - learning_rate: 5.0000e-05
# Epoch 7/2000
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 3s 36ms/step - loss: 0.0017 - val_loss: 0.0034 - learning_rate: 5.0000e-05
# Epoch 8/2000
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 3s 42ms/step - loss: 0.0013 - val_loss: 0.0031 - learning_rate: 5.0000e-05
# Epoch 9/2000
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 2s 28ms/step - loss: 0.0012 - val_loss: 0.0039 - learning_rate: 5.0000e-05
# Epoch 10/2000
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 3s 37ms/step - loss: 0.0014 - val_loss: 0.0027 - learning_rate: 5.0000e-05
# Epoch 11/2000
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 3s 36ms/step - loss: 0.0011 - val_loss: 0.0021 - learning_rate: 5.0000e-05
# Epoch 12/2000
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - loss: 0.0012 - val_loss: 0.0031 - learning_rate: 5.0000e-05
# Epoch 13/2000
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 2s 32ms/step - loss: 0.0010 - val_loss: 0.0026 - learning_rate: 5.0000e-05
# Epoch 14/2000
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 3s 36ms/step - loss: 8.9151e-04 - val_loss: 0.0027 - learning_rate: 5.0000e-05
# Epoch 15/2000
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - loss: 9.9639e-04 - val_loss: 0.0021 - learning_rate: 5.0000e-05
# Epoch 16/2000
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 7.7642e-04 - val_loss: 0.0023 - learning_rate: 5.0000e-05
# Epoch 17/2000
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 3s 35ms/step - loss: 9.0806e-04 - val_loss: 0.0030 - learning_rate: 5.0000e-05
# Epoch 18/2000
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 3s 36ms/step - loss: 8.2083e-04 - val_loss: 0.0020 - learning_rate: 5.0000e-05
# Epoch 19/2000
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 3s 37ms/step - loss: 9.0856e-04 - val_loss: 0.0021 - learning_rate: 5.0000e-05
# Epoch 20/2000
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 3s 37ms/step - loss: 7.3275e-04 - val_loss: 0.0016 - learning_rate: 5.0000e-05
# Epoch 21/2000
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - loss: 8.8805e-04 - val_loss: 0.0019 - learning_rate: 5.0000e-05
# Epoch 22/2000
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 3s 37ms/step - loss: 6.5239e-04 - val_loss: 0.0020 - learning_rate: 5.0000e-05
# Epoch 23/2000
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 3s 36ms/step - loss: 7.5670e-04 - val_loss: 0.0017 - learning_rate: 5.0000e-05
# Epoch 24/2000
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 2s 23ms/step - loss: 6.3541e-04 - val_loss: 0.0022 - learning_rate: 5.0000e-05
# Epoch 25/2000
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 3s 34ms/step - loss: 7.2973e-04 - val_loss: 0.0014 - learning_rate: 5.0000e-05
# Epoch 26/2000
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 3s 36ms/step - loss: 6.3931e-04 - val_loss: 0.0013 - learning_rate: 5.0000e-05
# Epoch 27/2000
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - loss: 6.2490e-04 - val_loss: 0.0018 - learning_rate: 5.0000e-05
# Epoch 28/2000
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 6.3435e-04 - val_loss: 0.0013 - learning_rate: 5.0000e-05
# Epoch 29/2000
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 3s 37ms/step - loss: 7.6769e-04 - val_loss: 0.0016 - learning_rate: 5.0000e-05
# Epoch 30/2000
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 3s 38ms/step - loss: 5.8852e-04 - val_loss: 0.0019 - learning_rate: 5.0000e-05
# Epoch 31/2000
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 3s 36ms/step - loss: 5.1906e-04 - val_loss: 0.0013 - learning_rate: 5.0000e-05
# Epoch 32/2000
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 3s 36ms/step - loss: 5.2313e-04 - val_loss: 0.0011 - learning_rate: 5.0000e-05
# Epoch 33/2000
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 5.6050e-04 - val_loss: 0.0020 - learning_rate: 5.0000e-05
# Epoch 34/2000
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 5.3247e-04 - val_loss: 0.0014 - learning_rate: 5.0000e-05
# Epoch 35/2000
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 3s 37ms/step - loss: 4.9625e-04 - val_loss: 0.0013 - learning_rate: 5.0000e-05
# Epoch 36/2000
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 3s 36ms/step - loss: 5.9678e-04 - val_loss: 0.0013 - learning_rate: 5.0000e-05
# Epoch 37/2000
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 3s 37ms/step - loss: 5.1960e-04 - val_loss: 0.0011 - learning_rate: 5.0000e-05
# Epoch 38/2000
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 3s 36ms/step - loss: 5.9145e-04 - val_loss: 0.0014 - learning_rate: 5.0000e-05
# Epoch 39/2000
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 3s 37ms/step - loss: 5.1553e-04 - val_loss: 9.1607e-04 - learning_rate: 5.0000e-05
# Epoch 40/2000
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - loss: 5.0432e-04 - val_loss: 0.0012 - learning_rate: 5.0000e-05
# Epoch 41/2000
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 3s 34ms/step - loss: 5.1329e-04 - val_loss: 0.0015 - learning_rate: 5.0000e-05
# Epoch 42/2000
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 3s 36ms/step - loss: 4.3862e-04 - val_loss: 0.0010 - learning_rate: 5.0000e-05
# Epoch 43/2000
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 3s 38ms/step - loss: 4.9290e-04 - val_loss: 0.0013 - learning_rate: 5.0000e-05
# Epoch 44/2000
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - loss: 4.6021e-04 - val_loss: 0.0012 - learning_rate: 5.0000e-05
# Epoch 45/2000
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 3s 38ms/step - loss: 4.5149e-04 - val_loss: 0.0012 - learning_rate: 5.0000e-05
# Epoch 46/2000
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 3s 36ms/step - loss: 4.5654e-04 - val_loss: 0.0011 - learning_rate: 5.0000e-05
# Epoch 47/2000
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - loss: 4.7017e-04 - val_loss: 0.0012 - learning_rate: 5.0000e-05
# Epoch 48/2000
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 3s 35ms/step - loss: 4.8603e-04 - val_loss: 0.0014 - learning_rate: 5.0000e-05
# Epoch 49/2000
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 3s 36ms/step - loss: 4.4558e-04 - val_loss: 9.1979e-04 - learning_rate: 5.0000e-05
# Epoch 50/2000
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 3s 36ms/step - loss: 5.0847e-04 - val_loss: 0.0011 - learning_rate: 5.0000e-05
# Epoch 51/2000
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - loss: 4.2652e-04 - val_loss: 0.0012 - learning_rate: 5.0000e-05
# Epoch 52/2000
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 3s 35ms/step - loss: 4.8714e-04 - val_loss: 0.0015 - learning_rate: 5.0000e-05
# Epoch 53/2000
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 3s 40ms/step - loss: 5.0217e-04 - val_loss: 8.9887e-04 - learning_rate: 5.0000e-05
# Epoch 54/2000
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 3s 40ms/step - loss: 4.4455e-04 - val_loss: 0.0011 - learning_rate: 5.0000e-05
# Epoch 55/2000
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - loss: 4.4226e-04 - val_loss: 6.2256e-04 - learning_rate: 5.0000e-05
# Epoch 56/2000
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - loss: 4.6250e-04 - val_loss: 0.0010 - learning_rate: 5.0000e-05
# Epoch 57/2000
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 3s 36ms/step - loss: 4.0875e-04 - val_loss: 7.0676e-04 - learning_rate: 5.0000e-05
# Epoch 58/2000
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 3s 36ms/step - loss: 4.6437e-04 - val_loss: 9.4496e-04 - learning_rate: 5.0000e-05
# Epoch 59/2000
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 3s 38ms/step - loss: 4.5171e-04 - val_loss: 5.6902e-04 - learning_rate: 5.0000e-05
# Epoch 60/2000
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - loss: 4.0880e-04 - val_loss: 0.0011 - learning_rate: 5.0000e-05
# Epoch 61/2000
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 3.9108e-04 - val_loss: 7.7326e-04 - learning_rate: 5.0000e-05
# Epoch 62/2000
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 3s 36ms/step - loss: 4.4048e-04 - val_loss: 5.3919e-04 - learning_rate: 5.0000e-05
# Epoch 63/2000
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 3s 38ms/step - loss: 4.5713e-04 - val_loss: 4.7105e-04 - learning_rate: 5.0000e-05
# Epoch 64/2000
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 3s 35ms/step - loss: 4.0195e-04 - val_loss: 7.8361e-04 - learning_rate: 5.0000e-05
# Epoch 65/2000
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 3s 36ms/step - loss: 4.6514e-04 - val_loss: 7.4353e-04 - learning_rate: 5.0000e-05
# Epoch 66/2000
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - loss: 4.0659e-04 - val_loss: 5.1649e-04 - learning_rate: 5.0000e-05
# Epoch 67/2000
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 3s 35ms/step - loss: 4.0981e-04 - val_loss: 8.8122e-04 - learning_rate: 5.0000e-05
# Epoch 68/2000
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 3s 39ms/step - loss: 4.3396e-04 - val_loss: 5.4690e-04 - learning_rate: 5.0000e-05
# Epoch 69/2000
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 3s 39ms/step - loss: 3.8233e-04 - val_loss: 8.6519e-04 - learning_rate: 5.0000e-05
# Epoch 70/2000
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 3s 41ms/step - loss: 4.0095e-04 - val_loss: 9.0024e-04 - learning_rate: 5.0000e-05
# Epoch 71/2000
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - loss: 4.1673e-04 - val_loss: 6.2457e-04 - learning_rate: 5.0000e-05
# Epoch 72/2000
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - loss: 3.9564e-04 - val_loss: 7.4685e-04 - learning_rate: 5.0000e-05
# Epoch 73/2000
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 3s 36ms/step - loss: 3.7890e-04 - val_loss: 8.1924e-04 - learning_rate: 5.0000e-05
# Epoch 74/2000
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 3s 38ms/step - loss: 3.6192e-04 - val_loss: 5.8377e-04 - learning_rate: 5.0000e-05
# Epoch 75/2000
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 3s 37ms/step - loss: 3.8877e-04 - val_loss: 9.0545e-04 - learning_rate: 5.0000e-05
# Epoch 76/2000
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 3s 37ms/step - loss: 4.0958e-04 - val_loss: 7.1357e-04 - learning_rate: 5.0000e-05
# Epoch 77/2000
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - loss: 3.8662e-04 - val_loss: 5.6350e-04 - learning_rate: 5.0000e-05
# Epoch 78/2000
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 3s 36ms/step - loss: 4.0221e-04 - val_loss: 4.5259e-04 - learning_rate: 5.0000e-05
# Epoch 79/2000
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 3s 36ms/step - loss: 4.1846e-04 - val_loss: 5.0858e-04 - learning_rate: 5.0000e-05
# Epoch 80/2000
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - loss: 3.7937e-04 - val_loss: 9.1187e-04 - learning_rate: 5.0000e-05
# Epoch 81/2000
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 3s 37ms/step - loss: 3.7444e-04 - val_loss: 9.6932e-04 - learning_rate: 5.0000e-05
# Epoch 82/2000
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 3s 36ms/step - loss: 3.8003e-04 - val_loss: 3.6913e-04 - learning_rate: 5.0000e-05
# Epoch 83/2000
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - loss: 3.8308e-04 - val_loss: 3.6207e-04 - learning_rate: 5.0000e-05
# Epoch 84/2000
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 3s 36ms/step - loss: 3.5592e-04 - val_loss: 4.6555e-04 - learning_rate: 5.0000e-05
# Epoch 85/2000
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 3s 39ms/step - loss: 3.6360e-04 - val_loss: 4.7864e-04 - learning_rate: 5.0000e-05
# Epoch 86/2000
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 3s 37ms/step - loss: 3.5621e-04 - val_loss: 7.1061e-04 - learning_rate: 5.0000e-05
# Epoch 87/2000
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - loss: 4.0439e-04 - val_loss: 5.5781e-04 - learning_rate: 5.0000e-05
# Epoch 88/2000
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 3s 35ms/step - loss: 3.3574e-04 - val_loss: 3.6723e-04 - learning_rate: 5.0000e-05
# Epoch 89/2000
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 3s 35ms/step - loss: 3.6521e-04 - val_loss: 4.1999e-04 - learning_rate: 5.0000e-05
# Epoch 90/2000
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - loss: 3.3832e-04 - val_loss: 3.3978e-04 - learning_rate: 5.0000e-05
# Epoch 91/2000
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 3.3272e-04 - val_loss: 6.6679e-04 - learning_rate: 5.0000e-05
# Epoch 92/2000
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 3s 36ms/step - loss: 3.3484e-04 - val_loss: 5.9132e-04 - learning_rate: 5.0000e-05
# Epoch 93/2000
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 3s 36ms/step - loss: 3.7789e-04 - val_loss: 8.5437e-04 - learning_rate: 5.0000e-05
# Epoch 94/2000
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 3s 41ms/step - loss: 3.6250e-04 - val_loss: 3.2231e-04 - learning_rate: 5.0000e-05
# Epoch 95/2000
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 3s 37ms/step - loss: 3.2644e-04 - val_loss: 3.7835e-04 - learning_rate: 5.0000e-05
# Epoch 96/2000
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 3.3886e-04 - val_loss: 3.3829e-04 - learning_rate: 5.0000e-05
# Epoch 97/2000
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - loss: 3.5020e-04 - val_loss: 3.3858e-04 - learning_rate: 5.0000e-05
# Epoch 98/2000
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 3s 36ms/step - loss: 3.5608e-04 - val_loss: 6.8373e-04 - learning_rate: 5.0000e-05
# Epoch 99/2000
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 3s 36ms/step - loss: 3.4768e-04 - val_loss: 3.9436e-04 - learning_rate: 5.0000e-05
# Epoch 100/2000
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 3s 37ms/step - loss: 3.5203e-04 - val_loss: 6.2184e-04 - learning_rate: 5.0000e-05
# Epoch 101/2000
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 3s 36ms/step - loss: 3.7959e-04 - val_loss: 6.8797e-04 - learning_rate: 5.0000e-05
# Epoch 102/2000
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 3.1739e-04
# Epoch 102: ReduceLROnPlateau reducing learning rate to 2.499999936844688e-05.
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - loss: 3.1742e-04 - val_loss: 3.6689e-04 - learning_rate: 5.0000e-05
# Epoch 103/2000
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 2s 32ms/step - loss: 3.0401e-04 - val_loss: 5.8714e-04 - learning_rate: 2.5000e-05
# Epoch 104/2000
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 3s 36ms/step - loss: 3.5152e-04 - val_loss: 3.5542e-04 - learning_rate: 2.5000e-05
# Epoch 105/2000
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - loss: 3.3893e-04 - val_loss: 4.0335e-04 - learning_rate: 2.5000e-05
# Epoch 106/2000
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 3.4747e-04 - val_loss: 3.0761e-04 - learning_rate: 2.5000e-05
# Epoch 107/2000
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 3s 36ms/step - loss: 3.6925e-04 - val_loss: 4.2999e-04 - learning_rate: 2.5000e-05
# Epoch 108/2000
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 3s 36ms/step - loss: 3.1249e-04 - val_loss: 5.0954e-04 - learning_rate: 2.5000e-05
# Epoch 109/2000
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 3s 38ms/step - loss: 3.3290e-04 - val_loss: 3.7570e-04 - learning_rate: 2.5000e-05
# Epoch 110/2000
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 3s 36ms/step - loss: 2.9305e-04 - val_loss: 3.9749e-04 - learning_rate: 2.5000e-05
# Epoch 111/2000
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 3s 36ms/step - loss: 3.2123e-04 - val_loss: 5.9052e-04 - learning_rate: 2.5000e-05
# Epoch 112/2000
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 2s 33ms/step - loss: 2.9627e-04 - val_loss: 4.6211e-04 - learning_rate: 2.5000e-05
# Epoch 113/2000
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 3.1669e-04 - val_loss: 5.2157e-04 - learning_rate: 2.5000e-05
# Epoch 114/2000
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 2s 29ms/step - loss: 3.1721e-04 - val_loss: 5.7676e-04 - learning_rate: 2.5000e-05
# Epoch 115/2000
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 3s 38ms/step - loss: 3.0421e-04 - val_loss: 2.9481e-04 - learning_rate: 2.5000e-05
# Epoch 116/2000
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 3s 37ms/step - loss: 3.3803e-04 - val_loss: 3.2032e-04 - learning_rate: 2.5000e-05
# Epoch 117/2000
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 3s 38ms/step - loss: 3.1391e-04 - val_loss: 6.6562e-04 - learning_rate: 2.5000e-05
# Epoch 118/2000
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 3s 37ms/step - loss: 3.1811e-04 - val_loss: 4.4248e-04 - learning_rate: 2.5000e-05
# Epoch 119/2000
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 2s 23ms/step - loss: 3.3278e-04 - val_loss: 2.9051e-04 - learning_rate: 2.5000e-05
# Epoch 120/2000
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 3.0879e-04 - val_loss: 4.8068e-04 - learning_rate: 2.5000e-05
# Epoch 121/2000
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 3s 36ms/step - loss: 3.0747e-04 - val_loss: 8.3165e-04 - learning_rate: 2.5000e-05
# Epoch 122/2000
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 3.4835e-04
# Epoch 122: ReduceLROnPlateau reducing learning rate to 1.249999968422344e-05.
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 3s 37ms/step - loss: 3.4817e-04 - val_loss: 3.1483e-04 - learning_rate: 2.5000e-05
# Epoch 123/2000
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 3s 39ms/step - loss: 3.1598e-04 - val_loss: 4.6896e-04 - learning_rate: 1.2500e-05
# Epoch 124/2000
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 3s 39ms/step - loss: 3.2367e-04 - val_loss: 3.8040e-04 - learning_rate: 1.2500e-05
# Epoch 125/2000
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - loss: 2.9118e-04 - val_loss: 3.9103e-04 - learning_rate: 1.2500e-05
# Epoch 126/2000
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 3s 37ms/step - loss: 3.1633e-04 - val_loss: 3.4301e-04 - learning_rate: 1.2500e-05
# Epoch 127/2000
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 3s 40ms/step - loss: 3.3660e-04 - val_loss: 3.9530e-04 - learning_rate: 1.2500e-05
# Epoch 128/2000
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 3s 37ms/step - loss: 3.2069e-04 - val_loss: 2.8971e-04 - learning_rate: 1.2500e-05
# Epoch 129/2000
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 3s 36ms/step - loss: 2.8911e-04 - val_loss: 3.3613e-04 - learning_rate: 1.2500e-05
# Epoch 130/2000
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - loss: 3.2185e-04 - val_loss: 4.0134e-04 - learning_rate: 1.2500e-05
# Epoch 131/2000
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 2.8133e-04 - val_loss: 3.8054e-04 - learning_rate: 1.2500e-05
# Epoch 132/2000
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 2s 33ms/step - loss: 2.9317e-04 - val_loss: 2.7293e-04 - learning_rate: 1.2500e-05
# Epoch 133/2000
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 3s 36ms/step - loss: 2.9190e-04 - val_loss: 3.7681e-04 - learning_rate: 1.2500e-05
# Epoch 134/2000
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 3s 36ms/step - loss: 3.1059e-04 - val_loss: 3.3544e-04 - learning_rate: 1.2500e-05
# Epoch 135/2000
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 3s 36ms/step - loss: 2.8598e-04 - val_loss: 3.1787e-04 - learning_rate: 1.2500e-05
# Epoch 136/2000
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - loss: 3.4998e-04 - val_loss: 3.6646e-04 - learning_rate: 1.2500e-05
# Epoch 137/2000
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 3s 36ms/step - loss: 3.0305e-04 - val_loss: 3.4018e-04 - learning_rate: 1.2500e-05
# Epoch 138/2000
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 3s 37ms/step - loss: 3.4197e-04 - val_loss: 5.3167e-04 - learning_rate: 1.2500e-05
# Epoch 139/2000
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 3s 36ms/step - loss: 2.8508e-04 - val_loss: 5.7856e-04 - learning_rate: 1.2500e-05
# Epoch 140/2000
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 3s 37ms/step - loss: 2.9801e-04 - val_loss: 3.9671e-04 - learning_rate: 1.2500e-05
# Epoch 141/2000
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - loss: 3.3207e-04 - val_loss: 2.7972e-04 - learning_rate: 1.2500e-05
# Epoch 142/2000
# 73/75 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 3.0778e-04
# Epoch 142: ReduceLROnPlateau reducing learning rate to 6.24999984211172e-06.
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 3.0749e-04 - val_loss: 3.1141e-04 - learning_rate: 1.2500e-05
# Epoch 143/2000
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 3s 38ms/step - loss: 2.9439e-04 - val_loss: 3.4181e-04 - learning_rate: 6.2500e-06
# Epoch 144/2000
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 3s 36ms/step - loss: 3.0026e-04 - val_loss: 3.4489e-04 - learning_rate: 6.2500e-06
# Epoch 145/2000
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 3s 35ms/step - loss: 3.0023e-04 - val_loss: 2.9180e-04 - learning_rate: 6.2500e-06
# Epoch 146/2000
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 3s 37ms/step - loss: 3.0308e-04 - val_loss: 3.2909e-04 - learning_rate: 6.2500e-06
# Epoch 147/2000
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 3s 35ms/step - loss: 2.6625e-04 - val_loss: 3.2492e-04 - learning_rate: 6.2500e-06
# Epoch 148/2000
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 3.0164e-04 - val_loss: 3.5103e-04 - learning_rate: 6.2500e-06
# Epoch 149/2000
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 2.6562e-04 - val_loss: 3.0483e-04 - learning_rate: 6.2500e-06
# Epoch 150/2000
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 3s 36ms/step - loss: 2.8704e-04 - val_loss: 3.2036e-04 - learning_rate: 6.2500e-06
# Epoch 151/2000
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 3s 37ms/step - loss: 3.2704e-04 - val_loss: 3.6345e-04 - learning_rate: 6.2500e-06
# Epoch 152/2000
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 3s 36ms/step - loss: 3.0045e-04 - val_loss: 3.8623e-04 - learning_rate: 6.2500e-06
# Epoch 153/2000
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 3s 38ms/step - loss: 2.9626e-04 - val_loss: 2.7748e-04 - learning_rate: 6.2500e-06
# Epoch 154/2000
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 3s 36ms/step - loss: 2.8013e-04 - val_loss: 2.5265e-04 - learning_rate: 6.2500e-06
# Epoch 155/2000
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - loss: 3.0933e-04 - val_loss: 3.0381e-04 - learning_rate: 6.2500e-06
# Epoch 156/2000
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 2.9886e-04 - val_loss: 3.2816e-04 - learning_rate: 6.2500e-06
# Epoch 157/2000
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 2s 32ms/step - loss: 3.1683e-04 - val_loss: 3.2801e-04 - learning_rate: 6.2500e-06
# Epoch 158/2000
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 3s 39ms/step - loss: 3.0544e-04 - val_loss: 3.1859e-04 - learning_rate: 6.2500e-06
# Epoch 159/2000
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 3s 38ms/step - loss: 2.7177e-04 - val_loss: 3.1298e-04 - learning_rate: 6.2500e-06
# Epoch 159: early stopping

# %% [markdown]
# We can examine what happens to the MSE loss during training
# - Training Loss ("Loss")- Measures the error on the training data during each iteration of model training.
# - Validation Loss ("val_loss")- Reflects the error on a separate validation dataset that the model has not seen during training.

# %%
loss = model.history.history['loss']
val_loss = model.history.history['val_loss']
plt.plot(loss, label='Training Loss')
plt.plot(val_loss, label='Validation Loss')

plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Plot of Loss per Increasing Epochs (Stand-Alone LSTM)')
plt.legend()

# %%
model.summary()
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ lstm_2 (LSTM)                   │ (None, 24, 30)         │         4,800 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 24, 30)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_3 (LSTM)                   │ (None, 60)             │        21,840 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_3 (Dropout)             │ (None, 60)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 1)              │            61 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 80,105 (312.91 KB)
#  Trainable params: 26,701 (104.30 KB)
#  Non-trainable params: 0 (0.00 B)
#  Optimizer params: 53,404 (208.61 KB)

# %% [markdown]
# ### Testing & Forecasting

# %%
## Predicting the test data
test_predict= model.predict(x_test)

## Comparing test values to actual valuesa
test_predict= target_scaler.inverse_transform(test_predict)
test_prices= y_test

print('Predicted', 'Actual')
for i in range(10):
    print(test_predict[i], test_prices[i])
# Out:
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 43ms/step
# Predicted Actual
# [34.490845] [34.7]
# [34.50352] [35.45]
# [34.48346] [35.3]
# [34.445038] [35.]
# [34.379498] [35.05]
# [34.272293] [34.75]
# [34.147305] [34.2]
# [34.00864] [34.]
# [33.848335] [33.85]
# [33.65518] [33.8]

# %%
test_prices.shape
# Out:
# (729, 1)

# %%
## Plotting the predictions
plt.figure(figsize= (20,10))
plt.plot(test_prices, color= 'blue', label= 'Actual Prices')
plt.plot(test_predict, color= 'green', label= 'Predicted Prices')

plt.ylabel('Closing Prices')
plt.title('Actual vs. Predicted Prices (Stand-Alone LSTM)')
plt.legend()

# %%
test_prices
# Out:
# array([[34.7 ],
#        [35.45],
#        [35.3 ],
#        [35.  ],
#        [35.05],
#        [34.75],
#        [34.2 ],
#        [34.  ],
#        [33.85],
#        [33.8 ],
#        [33.7 ],
#        [33.5 ],
#        [32.95],
#        [32.  ],
#        [32.2 ],
#        [32.25],
#        [32.4 ],
#        [31.85],
#        [30.2 ],
#        [30.3 ],
#        [30.45],
#        [29.45],
#        [28.05],
#        [27.8 ],
#        [26.65],
#        [26.35],
#        [26.55],
#        [26.85],
#        [26.45],
#        [26.25],
#        [26.  ],
#        [26.  ],
#        [26.2 ],
#        [26.35],
#        [26.4 ],
#        [26.45],
#        [26.6 ],
#        [26.7 ],
#        [26.5 ],
#        [26.35],
#        [25.7 ],
#        [25.05],
#        [24.3 ],
#        [24.35],
#        [24.  ],
#        [23.45],
#        [23.5 ],
#        [23.1 ],
#        [23.15],
#        [23.35],
#        [24.9 ],
#        [24.95],
#        [25.05],
#        [26.55],
#        [27.6 ],
#        [27.75],
#        [27.95],
#        [28.2 ],
#        [29.5 ],
#        [30.  ],
#        [32.05],
#        [31.45],
#        [30.  ],
#        [28.9 ],
#        [28.15],
#        [28.55],
#        [29.  ],
#        [29.5 ],
#        [29.  ],
#        [29.55],
#        [30.  ],
#        [29.95],
#        [29.15],
#        [29.75],
#        [29.6 ],
#        [30.  ],
#        [30.1 ],
#        [30.  ],
#        [30.45],
#        [31.8 ],
#        [31.15],
#        [31.15],
#        [31.1 ],
#        [31.1 ],
#        [31.05],
#        [31.25],
#        [30.1 ],
#        [29.8 ],
#        [29.1 ],
#        [28.45],
#        [28.05],
#        [28.25],
#        [28.2 ],
#        [27.95],
#        [27.85],
#        [28.05],
#        [29.05],
#        [31.05],
#        [29.85],
#        [29.9 ],
#        [29.25],
#        [28.65],
#        [28.2 ],
#        [26.85],
#        [26.55],
#        [26.8 ],
#        [27.55],
#        [27.5 ],
#        [27.5 ],
#        [27.4 ],
#        [27.05],
#        [26.25],
#        [25.95],
#        [25.15],
#        [24.95],
#        [24.75],
#        [24.45],
#        [23.7 ],
#        [23.65],
#        [24.75],
#        [25.95],
#        [26.35],
#        [25.85],
#        [25.55],
#        [25.5 ],
#        [25.5 ],
#        [25.45],
#        [24.95],
#        [24.55],
#        [24.4 ],
#        [24.95],
#        [25.3 ],
#        [24.85],
#        [25.1 ],
#        [25.  ],
#        [24.8 ],
#        [24.8 ],
#        [24.8 ],
#        [24.95],
#        [25.  ],
#        [25.15],
#        [25.5 ],
#        [25.25],
#        [25.1 ],
#        [25.05],
#        [25.25],
#        [25.25],
#        [25.25],
#        [25.35],
#        [25.  ],
#        [25.  ],
#        [24.85],
#        [24.65],
#        [24.7 ],
#        [24.45],
#        [24.35],
#        [24.5 ],
#        [24.35],
#        [23.65],
#        [23.85],
#        [24.1 ],
#        [24.1 ],
#        [24.3 ],
#        [24.9 ],
#        [25.  ],
#        [24.8 ],
#        [24.95],
#        [24.9 ],
#        [24.8 ],
#        [24.75],
#        [24.7 ],
#        [24.6 ],
#        [24.45],
#        [24.  ],
#        [24.15],
#        [24.05],
#        [23.9 ],
#        [23.9 ],
#        [23.5 ],
#        [23.35],
#        [22.95],
#        [22.65],
#        [22.25],
#        [22.  ],
#        [21.55],
#        [21.1 ],
#        [20.6 ],
#        [21.75],
#        [22.55],
#        [23.  ],
#        [23.05],
#        [23.55],
#        [23.25],
#        [23.25],
#        [23.05],
#        [23.4 ],
#        [24.  ],
#        [24.  ],
#        [24.5 ],
#        [24.45],
#        [24.  ],
#        [24.  ],
#        [24.1 ],
#        [23.9 ],
#        [23.75],
#        [23.7 ],
#        [23.7 ],
#        [23.6 ],
#        [23.65],
#        [23.5 ],
#        [23.45],
#        [23.5 ],
#        [23.4 ],
#        [23.35],
#        [23.  ],
#        [23.3 ],
#        [23.35],
#        [23.5 ],
#        [23.45],
#        [23.  ],
#        [22.55],
#        [20.95],
#        [20.95],
#        [20.6 ],
#        [19.6 ],
#        [19.1 ],
#        [18.  ],
#        [17.  ],
#        [16.35],
#        [17.95],
#        [18.95],
#        [19.1 ],
#        [19.  ],
#        [18.9 ],
#        [18.85],
#        [18.5 ],
#        [18.5 ],
#        [18.  ],
#        [18.1 ],
#        [18.15],
#        [18.  ],
#        [18.05],
#        [18.6 ],
#        [18.45],
#        [18.35],
#        [17.85],
#        [17.8 ],
#        [17.05],
#        [16.85],
#        [16.7 ],
#        [16.5 ],
#        [16.7 ],
#        [16.5 ],
#        [16.7 ],
#        [16.7 ],
#        [16.5 ],
#        [16.5 ],
#        [16.05],
#        [16.25],
#        [15.75],
#        [15.95],
#        [15.6 ],
#        [15.3 ],
#        [14.7 ],
#        [13.25],
#        [13.  ],
#        [14.3 ],
#        [15.5 ],
#        [14.85],
#        [15.  ],
#        [15.05],
#        [15.3 ],
#        [15.25],
#        [15.05],
#        [15.05],
#        [15.25],
#        [15.9 ],
#        [16.6 ],
#        [16.95],
#        [16.95],
#        [17.  ],
#        [16.95],
#        [16.7 ],
#        [16.6 ],
#        [15.75],
#        [15.05],
#        [14.95],
#        [14.85],
#        [14.9 ],
#        [16.05],
#        [16.25],
#        [16.8 ],
#        [17.45],
#        [17.5 ],
#        [17.5 ],
#        [17.4 ],
#        [17.45],
#        [17.5 ],
#        [17.75],
#        [17.8 ],
#        [17.7 ],
#        [17.85],
#        [18.9 ],
#        [19.55],
#        [19.7 ],
#        [19.7 ],
#        [19.4 ],
#        [19.2 ],
#        [19.3 ],
#        [18.55],
#        [18.15],
#        [18.05],
#        [18.  ],
#        [17.85],
#        [16.8 ],
#        [16.15],
#        [17.25],
#        [16.6 ],
#        [16.9 ],
#        [17.35],
#        [16.9 ],
#        [16.8 ],
#        [16.8 ],
#        [16.75],
#        [16.4 ],
#        [16.35],
#        [16.15],
#        [16.05],
#        [15.9 ],
#        [15.9 ],
#        [15.  ],
#        [15.95],
#        [16.  ],
#        [15.95],
#        [15.9 ],
#        [15.55],
#        [15.75],
#        [15.5 ],
#        [15.45],
#        [15.45],
#        [15.5 ],
#        [15.4 ],
#        [15.1 ],
#        [15.1 ],
#        [15.1 ],
#        [15.1 ],
#        [15.25],
#        [15.5 ],
#        [15.75],
#        [15.35],
#        [15.3 ],
#        [15.5 ],
#        [15.75],
#        [15.6 ],
#        [15.4 ],
#        [15.  ],
#        [14.95],
#        [15.  ],
#        [14.95],
#        [14.9 ],
#        [14.7 ],
#        [14.6 ],
#        [14.6 ],
#        [14.65],
#        [14.7 ],
#        [14.65],
#        [14.5 ],
#        [14.  ],
#        [14.  ],
#        [13.9 ],
#        [14.  ],
#        [13.95],
#        [13.95],
#        [13.8 ],
#        [13.8 ],
#        [13.8 ],
#        [13.6 ],
#        [13.  ],
#        [12.5 ],
#        [12.45],
#        [12.5 ],
#        [12.5 ],
#        [12.45],
#        [12.3 ],
#        [12.1 ],
#        [11.65],
#        [11.95],
#        [12.  ],
#        [12.45],
#        [13.3 ],
#        [13.5 ],
#        [13.3 ],
#        [13.5 ],
#        [13.5 ],
#        [13.45],
#        [13.4 ],
#        [13.45],
#        [13.7 ],
#        [13.6 ],
#        [13.7 ],
#        [13.45],
#        [14.  ],
#        [14.  ],
#        [14.05],
#        [14.05],
#        [14.5 ],
#        [14.8 ],
#        [14.6 ],
#        [14.55],
#        [14.55],
#        [14.5 ],
#        [14.45],
#        [14.4 ],
#        [14.1 ],
#        [13.85],
#        [13.5 ],
#        [13.5 ],
#        [13.55],
#        [13.55],
#        [13.6 ],
#        [13.7 ],
#        [13.9 ],
#        [13.75],
#        [13.65],
#        [13.6 ],
#        [13.6 ],
#        [13.85],
#        [13.65],
#        [13.8 ],
#        [13.9 ],
#        [13.9 ],
#        [13.9 ],
#        [13.9 ],
#        [14.  ],
#        [13.95],
#        [13.95],
#        [13.9 ],
#        [13.8 ],
#        [13.6 ],
#        [13.45],
#        [13.1 ],
#        [13.1 ],
#        [13.55],
#        [13.6 ],
#        [13.5 ],
#        [13.5 ],
#        [13.45],
#        [13.45],
#        [13.15],
#        [13.2 ],
#        [13.05],
#        [13.2 ],
#        [13.2 ],
#        [13.  ],
#        [13.05],
#        [13.1 ],
#        [13.4 ],
#        [13.5 ],
#        [13.4 ],
#        [13.4 ],
#        [13.4 ],
#        [13.75],
#        [13.65],
#        [13.5 ],
#        [13.25],
#        [13.5 ],
#        [13.5 ],
#        [13.5 ],
#        [13.75],
#        [13.9 ],
#        [13.9 ],
#        [14.15],
#        [14.5 ],
#        [14.6 ],
#        [15.  ],
#        [15.2 ],
#        [14.6 ],
#        [14.8 ],
#        [15.4 ],
#        [16.15],
#        [16.75],
#        [17.6 ],
#        [19.25],
#        [19.3 ],
#        [17.75],
#        [17.55],
#        [18.  ],
#        [17.7 ],
#        [17.55],
#        [16.8 ],
#        [16.65],
#        [16.65],
#        [16.95],
#        [17.05],
#        [16.95],
#        [16.75],
#        [16.35],
#        [16.  ],
#        [16.1 ],
#        [16.25],
#        [16.35],
#        [16.35],
#        [16.3 ],
#        [16.  ],
#        [15.95],
#        [16.  ],
#        [15.95],
#        [15.75],
#        [15.65],
#        [15.95],
#        [16.5 ],
#        [17.35],
#        [17.35],
#        [17.25],
#        [17.25],
#        [17.4 ],
#        [17.95],
#        [18.3 ],
#        [18.9 ],
#        [18.  ],
#        [17.75],
#        [17.8 ],
#        [18.5 ],
#        [18.35],
#        [18.05],
#        [17.9 ],
#        [18.  ],
#        [18.  ],
#        [18.05],
#        [18.35],
#        [18.35],
#        [18.1 ],
#        [18.05],
#        [18.1 ],
#        [18.1 ],
#        [18.2 ],
#        [18.3 ],
#        [18.5 ],
#        [18.7 ],
#        [18.15],
#        [18.1 ],
#        [18.05],
#        [17.85],
#        [17.2 ],
#        [17.3 ],
#        [17.45],
#        [17.4 ],
#        [17.35],
#        [17.2 ],
#        [17.3 ],
#        [17.3 ],
#        [17.3 ],
#        [17.1 ],
#        [17.05],
#        [17.05],
#        [17.  ],
#        [17.  ],
#        [16.75],
#        [16.45],
#        [16.4 ],
#        [16.2 ],
#        [16.15],
#        [15.95],
#        [15.55],
#        [15.1 ],
#        [15.3 ],
#        [16.  ],
#        [15.9 ],
#        [15.35],
#        [15.05],
#        [14.4 ],
#        [14.85],
#        [14.7 ],
#        [14.75],
#        [14.8 ],
#        [14.8 ],
#        [14.65],
#        [14.6 ],
#        [14.75],
#        [14.85],
#        [14.95],
#        [15.  ],
#        [15.  ],
#        [15.05],
#        [15.  ],
#        [14.9 ],
#        [14.8 ],
#        [14.55],
#        [14.5 ],
#        [14.5 ],
#        [14.7 ],
#        [14.7 ],
#        [14.7 ],
#        [14.9 ],
#        [14.8 ],
#        [14.85],
#        [15.15],
#        [15.3 ],
#        [15.  ],
#        [15.3 ],
#        [15.45],
#        [15.3 ],
#        [15.25],
#        [15.2 ],
#        [15.  ],
#        [15.  ],
#        [15.  ],
#        [15.1 ],
#        [15.05],
#        [15.05],
#        [15.  ],
#        [15.  ],
#        [15.  ],
#        [15.  ],
#        [15.  ],
#        [14.95],
#        [14.9 ],
#        [15.  ],
#        [15.3 ],
#        [15.5 ],
#        [15.35],
#        [15.55],
#        [15.55],
#        [15.85],
#        [15.85],
#        [16.15],
#        [16.15],
#        [16.5 ],
#        [16.75],
#        [17.4 ],
#        [17.35],
#        [16.75],
#        [16.7 ],
#        [16.45],
#        [16.35],
#        [15.7 ],
#        [15.65],
#        [15.4 ],
#        [15.3 ],
#        [15.3 ],
#        [15.25],
#        [15.15],
#        [15.  ],
#        [14.9 ],
#        [14.8 ],
#        [14.9 ],
#        [14.9 ],
#        [14.85],
#        [14.65],
#        [14.4 ],
#        [14.4 ],
#        [15.  ],
#        [15.35],
#        [15.25],
#        [15.4 ],
#        [15.95],
#        [16.25],
#        [16.55],
#        [17.6 ],
#        [17.  ],
#        [17.  ],
#        [17.1 ],
#        [17.25],
#        [17.6 ],
#        [17.6 ],
#        [17.6 ],
#        [17.5 ],
#        [17.2 ],
#        [17.1 ],
#        [17.15],
#        [17.05],
#        [17.2 ],
#        [17.35],
#        [17.6 ],
#        [17.7 ],
#        [17.8 ],
#        [17.95],
#        [18.1 ],
#        [18.2 ],
#        [18.1 ],
#        [18.25],
#        [18.6 ],
#        [18.6 ],
#        [18.9 ],
#        [19.  ],
#        [18.9 ],
#        [18.9 ],
#        [18.9 ],
#        [18.8 ],
#        [18.85],
#        [18.3 ],
#        [17.7 ],
#        [17.2 ],
#        [17.6 ],
#        [17.85],
#        [18.45],
#        [18.15],
#        [17.95],
#        [17.9 ],
#        [17.75],
#        [17.7 ],
#        [17.95],
#        [18.1 ],
#        [18.5 ],
#        [18.7 ],
#        [18.95],
#        [18.85],
#        [18.8 ],
#        [18.7 ],
#        [18.5 ],
#        [18.15],
#        [18.1 ],
#        [17.95],
#        [18.1 ],
#        [17.4 ],
#        [17.7 ],
#        [17.95],
#        [18.05],
#        [18.  ],
#        [18.  ],
#        [17.95],
#        [17.85],
#        [17.75],
#        [17.8 ],
#        [17.7 ],
#        [17.6 ],
#        [17.55],
#        [17.75],
#        [17.75]])

# %%
## Performance accuracy (LSTM) for last n days
print('mse=', mean_squared_error(test_prices[-n:], test_predict[-n:]))
print('rmse=', root_mean_squared_error(test_prices[-n:], test_predict[-n:]))
print('mae=', mean_absolute_error(test_prices[-n:], test_predict[-n:]))
print('mape=', mean_absolute_percentage_error(test_prices[-n:], test_predict[-n:]))
# print('r2=', r2_score(test_prices[-n:], test_predict[-n:]))
# Out:
# mse= 0.06118649333857093
# rmse= 0.24735903730927425
# mae= 0.13920323689778633
# mape= 0.007910837374364214

# %% [markdown]
# ARIMA & LSTM Predictions plotted. We first prepare the data for plotting

# %%
n_shift= 5

full_arima_prices_array= np.array(full_arima_prices)
full_arima_prices_array = np.roll(full_arima_prices_array, n_shift)
full_arima_prices_array[:n_shift] = 0
test_arima_prices= full_arima_prices_array[-len(test_prices):]
test_arima_prices
# Out:
# array([33.9160144 , 34.91024317, 35.57952052, 35.24889679, 34.94490549,
#        35.05625767, 34.67268517, 34.11296304, 34.00814072, 33.85632336,
#        33.84074335, 33.71822641, 33.49549332, 32.87119838, 31.86177367,
#        32.34867586, 32.29451016, 32.49757039, 31.75620576, 29.91009767,
#        30.46957739, 30.52139584, 29.31823161, 27.88640187, 27.90070865,
#        26.50210057, 26.48907246, 26.70978884, 27.00732705, 26.4202651 ,
#        26.28160802, 25.98224072, 26.05207591, 26.27498886, 26.3977141 ,
#        26.41824867, 26.46121385, 26.62601465, 26.70675623, 26.44492786,
#        26.32581162, 25.5658154 , 24.96917133, 24.20828728, 24.4658603 ,
#        23.98261135, 23.43016102, 23.60291445, 23.06014787, 23.24830005,
#        23.42718879, 25.25943953, 24.85872763, 25.06194816, 26.80112288,
#        27.66202625, 27.65344714, 27.88501367, 28.13443075, 29.68777039,
#        29.94707995, 32.39607874, 31.06333396, 29.64044451, 28.64432142,
#        28.02882053, 28.73520035, 29.14086237, 29.64764629, 28.88146611,
#        29.70725246, 30.03705099, 29.90902916, 28.96068961, 29.91499504,
#        29.51061061, 30.12092214, 30.08214799, 29.96946195, 30.53912819,
#        32.04276394, 30.89356185, 31.16965068, 31.02138242, 31.0878826 ,
#        31.03058511, 31.29497508, 29.8358102 , 29.83019372, 28.97798765,
#        28.41935671, 28.06975255, 28.39478369, 28.24797248, 27.9634274 ,
#        27.88292722, 28.12868221, 29.27927089, 31.4229453 , 29.42720824,
#        29.95053876, 29.0011937 , 28.5551304 , 28.1451406 , 26.62362098,
#        26.64228034, 26.94008348, 27.78888428, 27.50147895, 27.53531145,
#        27.37020839, 26.98057785, 26.10661782, 25.95916078, 25.0298701 ,
#        25.02565472, 24.77797887, 24.47154306, 23.61828749, 23.74771307,
#        25.04196335, 26.18362685, 26.37307677, 25.6779651 , 25.45539837,
#        25.45838742, 25.4927101 , 25.44563015, 24.85349196, 24.5106572 ,
#        24.4119727 , 25.11331136, 25.37020228, 24.75183528, 25.1841497 ,
#        24.94546272, 24.7737899 , 24.81408779, 24.80569132, 24.99525287,
#        25.0081122 , 25.1842936 , 25.5620254 , 25.1646805 , 25.0781389 ,
#        25.03470958, 25.29916178, 25.24270061, 25.25715484, 25.36944951,
#        24.91623325, 25.02869761, 24.81825546, 24.63462364, 24.73963054,
#        24.40909038, 24.36842462, 24.55463336, 24.32662119, 23.52849886,
#        23.95775933, 24.15628725, 24.11892872, 24.35926474, 25.01486666,
#        24.97335787, 24.73686862, 24.96747809, 24.85622411, 24.77704979,
#        24.73959367, 24.6924873 , 24.58767807, 24.43277425, 23.92369831,
#        24.231042  , 24.03532111, 23.90577708, 23.92756321, 23.43010265,
#        23.36783818, 22.89206446, 22.64664903, 22.21736923, 22.01719323,
#        21.51473115, 21.08543277, 20.5733286 , 22.09068396, 22.68624168,
#        23.07935354, 23.00258006, 23.60530221, 23.09649446, 23.23830041,
#        22.96783708, 23.48008185, 24.09670674, 23.95456058, 24.59188594,
#        24.36572093, 23.8826248 , 24.00277357, 24.10734788, 23.858816  ,
#        23.74066815, 23.7048249 , 23.71685426, 23.59428968, 23.68231223,
#        23.47430034, 23.46304034, 23.52293186, 23.38721813, 23.35834756,
#        22.93573074, 23.40348056, 23.34946827, 23.54914395, 23.42919496,
#        22.906216  , 22.48466963, 20.64546779, 21.1058854 , 20.57478288,
#        19.5097664 , 19.13979816, 17.86995668, 16.96177979, 16.37848475,
#        18.45830448, 19.153448  , 19.13897528, 18.95075414, 18.83667177,
#        18.81164467, 18.41185969, 18.52346618, 17.89534177, 18.17946958,
#        18.16953005, 17.99462624, 18.08964456, 18.72595219, 18.38699264,
#        18.34383041, 17.73295628, 17.82692013, 16.90011221, 16.89442313,
#        16.71098418, 16.51931693, 16.80215665, 16.47697926, 16.79008179,
#        16.69847996, 16.47365728, 16.52027794, 15.95852604, 16.34254625,
#        15.63939584, 16.05980462, 15.52269138, 15.29228268, 14.60959527,
#        13.01306996, 13.09985958, 14.66231886, 15.75411317, 14.67605816,
#        15.06445005, 14.99471356, 15.34126933, 15.2082293 , 15.00106124,
#        15.05170129, 15.28895232, 16.03061573, 16.70198173, 16.95846864,
#        16.88404323, 16.95697978, 16.88806514, 16.62081014, 16.57970937,
#        15.56801824, 14.97578687, 15.00322179, 14.88952133, 14.9828532 ,
#        16.3412039 , 16.23469852, 16.91362601, 17.50639726, 17.42125028,
#        17.44587881, 17.32131446, 17.43168262, 17.48511098, 17.79088251,
#        17.78355417, 17.66692136, 17.87658637, 19.10576258, 19.60341675,
#        19.66433246, 19.63157066, 19.27327963, 19.13685443, 19.3134685 ,
#        18.37946406, 18.13251735, 18.07005381, 18.03797289, 17.86577664,
#        16.61941258, 16.12118155, 17.5737377 , 16.44087128, 17.07975147,
#        17.42587067, 16.79277436, 16.81705651, 16.79687117, 16.75212867,
#        16.34201726, 16.37796249, 16.12392864, 16.06865065, 15.89614829,
#        15.93536157, 14.82715896, 16.24904338, 15.95649293, 15.978261  ,
#        15.88375961, 15.47215584, 15.8212251 , 15.43600712, 15.47686569,
#        15.46071429, 15.52673016, 15.38780021, 15.0527623 , 15.13053294,
#        15.11192079, 15.12084258, 15.29696402, 15.55237715, 15.79034729,
#        15.24065362, 15.30896761, 15.53402999, 15.79695921, 15.55467593,
#        15.36472256, 14.91980894, 14.9742811 , 15.0293786 , 14.96209771,
#        14.91329356, 14.67341131, 14.60636051, 14.62067131, 14.67896024,
#        14.72359728, 14.64673819, 14.4779042 , 13.90794708, 14.04755882,
#        13.8946474 , 14.06127291, 13.95344046, 13.97268706, 13.77725874,
#        13.82158998, 13.80864079, 13.56959513, 12.89614081, 12.44986272,
#        12.5002692 , 12.55765356, 12.54494934, 12.47333501, 12.29276309,
#        12.08419447, 11.58342135, 12.06948746, 12.01139737, 12.57551197,
#        13.45654052, 13.47551024, 13.21707003, 13.5099318 , 13.447251  ,
#        13.42329203, 13.37638331, 13.45577693, 13.74781651, 13.55959419,
#        13.72764663, 13.37881027, 14.13753157, 13.95396095, 14.0661455 ,
#        14.02870154, 14.5869267 , 14.82098269, 14.52503467, 14.5312861 ,
#        14.52973581, 14.48335097, 14.44277886, 14.39467074, 14.04390915,
#        13.8270376 , 13.45496618, 13.55042793, 13.58926867, 13.57935948,
#        13.63296292, 13.73096871, 13.94445768, 13.705765  , 13.63884993,
#        13.59086098, 13.60807662, 13.91223576, 13.59508399, 13.85307053,
#        13.90537221, 13.89718073, 13.89776371, 13.89584791, 14.02019552,
#        13.93146695, 13.95465589, 13.8873195 , 13.78452259, 13.56797132,
#        13.43994981, 13.04758188, 13.14600333, 13.66879662, 13.6033347 ,
#        13.49012095, 13.50106328, 13.43487564, 13.45653943, 13.08854582,
#        13.24050726, 13.02097496, 13.26205913, 13.19964559, 12.97026823,
#        13.08089784, 13.11228589, 13.47303103, 13.50393903, 13.37113534,
#        13.39704894, 13.39110939, 13.82511738, 13.60099759, 13.47446285,
#        13.19561124, 13.57280909, 13.48829565, 13.51445317, 13.80449953,
#        13.91369571, 13.88785337, 14.1939204 , 14.54412543, 14.58506408,
#        15.06116713, 15.18621079, 14.43225215, 14.86130748, 15.49247553,
#        16.2732718 , 16.81294358, 17.70169293, 19.48196224, 19.11124166,
#        17.32184533, 17.510435  , 18.04857592, 17.6221771 , 17.56212097,
#        16.64920299, 16.69238014, 16.68508719, 17.06192329, 17.08462971,
#        16.94274495, 16.71768977, 16.27982606, 15.96393356, 16.16733618,
#        16.30572893, 16.39383533, 16.35980548, 16.29504018, 15.94030638,
#        15.96591284, 16.02233184, 15.95360718, 15.72548829, 15.65370154,
#        16.03372867, 16.61145561, 17.50229412, 17.27394028, 17.19553199,
#        17.20447683, 17.40026377, 18.04127142, 18.321056  , 18.98511233,
#        17.72298053, 17.72918637, 17.79107986, 18.66087986, 18.28043527,
#        18.00289044, 17.87018336, 18.02979476, 18.00393223, 18.07483132,
#        18.41694929, 18.33045943, 18.04566184, 18.04856108, 18.11138882,
#        18.10541236, 18.23044285, 18.31840186, 18.53856624, 18.72555584,
#        18.00962955, 18.12185893, 18.03387633, 17.82852785, 17.09090988,
#        17.38898241, 17.49874642, 17.41895341, 17.36597741, 17.18193305,
#        17.34402242, 17.30305979, 17.31348088, 17.0627225 , 17.06046901,
#        17.06034795, 17.00291714, 17.01607765, 16.70543512, 16.41479648,
#        16.42300268, 16.18087234, 16.18188837, 15.93286043, 15.50362291,
#        15.05556477, 15.40548502, 16.1726393 , 15.86313979, 15.25289405,
#        15.01277048, 14.28333548, 15.02534162, 14.66648087, 14.81868045,
#        14.82063677, 14.81161849, 14.62645903, 14.60629952, 14.79220224,
#        14.87079407, 14.97264371, 15.00291929, 14.99246872, 15.05539719,
#        14.98097127, 14.88061262, 14.78506458, 14.50737734, 14.51771352,
#        14.51682404, 14.76301372, 14.69970861, 14.70964085, 14.9426241 ,
#        14.76309743, 14.86894537, 15.20491904, 15.30913506, 14.92032908,
#        15.37529762, 15.44720823, 15.25903705, 15.2416203 , 15.18366882,
#        14.96244924, 15.02093957, 15.00807748, 15.13598521, 15.04155914,
#        15.06110646, 14.99144246, 15.00874346, 15.00471143, 15.00626838,
#        15.00527028, 14.94383952, 14.89748951, 15.03006006, 15.3631741 ,
#        15.52535179, 15.3001233 , 15.59202785, 15.51990646, 15.91132901,
#        15.81675333, 16.20761557, 16.11039333, 16.56434331, 16.7577014 ,
#        17.50669801, 17.26299032, 16.59495732, 16.69479369, 16.38123137,
#        16.36228246, 15.58200902, 15.71316953, 15.37478713, 15.34211497,
#        15.34138343, 15.2726063 , 15.15906988, 14.99445386, 14.90671318,
#        14.80344519, 14.94866174, 14.91015916, 14.85523248, 14.61840654,
#        14.36878996, 14.42952594, 15.14691823, 15.39921103, 15.21012921,
#        15.42113735, 16.03239216, 16.25857438, 16.57333378, 17.76800948,
#        16.74994257, 17.00590762, 17.05907711, 17.2594925 , 17.65429401,
#        17.56170969, 17.58579608, 17.45664678, 17.13070932, 17.0968451 ,
#        17.1730938 , 17.04116055, 17.25603191, 17.38031248, 17.65214309,
#        17.70183951, 17.80683732, 17.96041556, 18.10772625, 18.19735537,
#        18.05651831, 18.27606444, 18.65233637, 18.56843142, 18.95484924,
#        18.97821757, 18.85668837, 18.88781496, 18.88520736, 18.77420971,
#        18.8674846 , 18.17848056, 17.62072385, 17.14859622, 17.76054774,
#        17.92270576, 18.60952693, 18.05175546, 17.92675867, 17.88267644,
#        17.722165  , 17.71138034, 18.01902858, 18.12682106, 18.58457836,
#        18.70730173, 18.97721727, 18.78491119, 18.77351197, 18.65945616,
#        18.45593626, 18.08908619, 18.12365305, 17.93794676, 18.17061846,
#        17.25800353, 17.84104957, 17.99369344, 18.08674651, 17.99079043,
#        17.98945137, 17.98546091, 17.98520508, 17.98743431, 17.99054268,
#        17.99412381, 17.99787405, 18.00160384, 18.00526431])

# %%
## Standalone LSTM Predictions
plt.figure(figsize= (20,10))
plt.plot(test_prices, color= 'blue', label= 'Actual Prices', linestyle= '--', marker= 'o')
plt.plot(test_predict, color= 'green', label= 'Predicted Prices (LSTM)', linestyle= '--', marker= 'o')
# plt.plot(test_arima_prices, color= 'red', label= 'Predicted Prices (ARIMA)')

plt.xlim(len(test_predict)-n-5, len(test_predict))
plt.axvline(x= len(test_predict)-n, linestyle= '--', color= 'red')


plt.ylabel('Closing Prices')
plt.title('Actual vs. Predicted Prices')
plt.grid()
plt.legend()

# %% [markdown]
# ### Arithmetic Average Hybrid

# %%
test_lstm_prices= test_predict.reshape(-1)
test_lstm_prices.shape
# Out:
# (729,)

# %%
# Average of ARIMA and LSTM predictions
arith_pred= np.add(test_arima_prices, test_lstm_prices)/2
arith_pred
# Out:
# array([34.20342956, 34.70688207, 35.03148999, 34.84696732, 34.66220151,
#        34.66427538, 34.40999485, 34.06080166, 33.92823799, 33.75575262,
#        33.64113774, 33.4631133 , 33.22475929, 32.78897558, 32.15083656,
#        32.26042611, 32.09985174, 32.03099078, 31.46644078, 30.35097626,
#        30.40707664, 30.16945513, 29.30715276, 28.33217322, 28.08299326,
#        27.15208846, 26.94683249, 26.87801148, 26.87048577, 26.44411273,
#        26.26871653, 26.04041865, 26.02668932, 26.11411415, 26.16743158,
#        26.18110062, 26.20570077, 26.28071305, 26.29592305, 26.11456617,
#        25.97615921, 25.4883425 , 25.07323255, 24.56424477, 24.55319211,
#        24.17796263, 23.79562117, 23.80122453, 23.48017293, 23.59479402,
#        23.76393028, 24.80400375, 24.77867087, 25.10146301, 26.22731601,
#        26.92953626, 27.22818612, 27.66237073, 28.08745997, 29.15324856,
#        29.51660886, 30.90348561, 30.34204124, 29.68571984, 29.20331382,
#        28.90023065, 29.25963185, 29.45559735, 29.68995874, 29.29458437,
#        29.69388769, 29.83398093, 29.75521763, 29.27239135, 29.75217144,
#        29.58237268, 29.92953494, 29.96129818, 29.98260428, 30.34912151,
#        31.17328512, 30.66946579, 30.85661012, 30.80773024, 30.84604148,
#        30.77601662, 30.83127965, 29.997041  , 29.86603222, 29.2968809 ,
#        28.87380856, 28.56664507, 28.61872134, 28.48158073, 28.30270331,
#        28.262293  , 28.43594793, 29.06188047, 30.16929068, 29.16891494,
#        29.38471133, 28.84023747, 28.52162286, 28.20806739, 27.34668922,
#        27.27350128, 27.34750508, 27.69164425, 27.45914402, 27.36999166,
#        27.16124517, 26.83058281, 26.23853917, 25.99280881, 25.35384706,
#        25.18892618, 24.92352961, 24.6648811 , 24.17900249, 24.23292827,
#        24.90666188, 25.51479087, 25.65370052, 25.34643647, 25.26425448,
#        25.28221991, 25.30519675, 25.28110651, 24.9761711 , 24.80391544,
#        24.76206812, 25.11327628, 25.23951017, 24.92793771, 25.13808391,
#        25.00882031, 24.91799809, 24.94312903, 24.94749478, 25.0513059 ,
#        25.07097829, 25.17275231, 25.37141816, 25.1814623 , 25.1507428 ,
#        25.13777525, 25.27410405, 25.24714853, 25.24450321, 25.2841701 ,
#        25.03321752, 25.05539399, 24.91584446, 24.78343922, 24.78055898,
#        24.56022375, 24.48888074, 24.52307855, 24.35484654, 23.92745649,
#        24.13034031, 24.2291322 , 24.22875013, 24.37974853, 24.73717252,
#        24.74704347, 24.65798795, 24.79739299, 24.75683692, 24.72097576,
#        24.69750603, 24.66060808, 24.58026653, 24.46743712, 24.17140574,
#        24.27380805, 24.1142916 , 23.97370534, 23.89497019, 23.54399172,
#        23.39673628, 23.02969236, 22.76259835, 22.41032513, 22.19192334,
#        21.8446077 , 21.5767206 , 21.31852942, 22.1105199 , 22.46530082,
#        22.73400794, 22.77347535, 23.1667735 , 23.00597848, 23.17806725,
#        23.15599095, 23.51850524, 23.93186205, 23.95516267, 24.34283132,
#        24.27758035, 24.07129821, 24.14994445, 24.20322152, 24.06862824,
#        23.99086993, 23.94563888, 23.91896638, 23.81871409, 23.820284  ,
#        23.66997049, 23.61983728, 23.60814562, 23.49925692, 23.45279725,
#        23.21146431, 23.41093637, 23.32895185, 23.35111769, 23.19047048,
#        22.77911584, 22.38994643, 21.26594354, 21.25029606, 20.71054627,
#        19.9070591 , 19.46510363, 18.59708104, 17.96871243, 17.5666237 ,
#        18.53963331, 18.84722609, 18.81706436, 18.70588873, 18.63373467,
#        18.60624176, 18.38681421, 18.42557529, 18.10522456, 18.24332213,
#        18.23642976, 18.15301667, 18.19920976, 18.50244429, 18.29950962,
#        18.22938648, 17.85696047, 17.82439165, 17.27661041, 17.18716174,
#        17.01476428, 16.8430096 , 16.91266547, 16.68038797, 16.77170124,
#        16.65957419, 16.48204501, 16.44257496, 16.09505148, 16.21392525,
#        15.76492793, 15.8551701 , 15.46750719, 15.23558216, 14.78164242,
#        13.90461771, 13.91531008, 14.68019135, 15.22251986, 14.69561308,
#        14.91002168, 14.90070713, 15.10874788, 15.09119284, 15.05430879,
#        15.16513526, 15.38999103, 15.88188501, 16.3366972 , 16.57174168,
#        16.61411215, 16.69198419, 16.66858186, 16.51108008, 16.43528048,
#        15.87555613, 15.52911219, 15.50502123, 15.44891773, 15.52193941,
#        16.24841128, 16.26565992, 16.68805042, 17.0722971 , 17.11781356,
#        17.21622744, 17.23471481, 17.36728861, 17.47884642, 17.72423859,
#        17.8174191 , 17.87129008, 18.09965202, 18.83743959, 19.20085064,
#        19.31669573, 19.35084621, 19.19742892, 19.12468351, 19.17903688,
#        18.65045781, 18.43512083, 18.30513131, 18.16457055, 17.93917685,
#        17.20651205, 16.85530761, 17.49319247, 16.86228325, 17.12401747,
#        17.2412814 , 16.87271126, 16.83183472, 16.76414012, 16.68314651,
#        16.42107634, 16.36933632, 16.17987566, 16.09716102, 15.95310382,
#        15.92846665, 15.34341766, 16.03222128, 15.86492421, 15.85279512,
#        15.78355222, 15.557902  , 15.71198222, 15.49585943, 15.48962685,
#        15.45400522, 15.45548754, 15.35805988, 15.16968884, 15.19568239,
#        15.17908357, 15.18141634, 15.27780215, 15.41919299, 15.55106364,
#        15.29077177, 15.33762933, 15.45616056, 15.58664861, 15.45229524,
#        15.33665672, 15.0877221 , 15.0834855 , 15.07621465, 15.00390652,
#        14.93958555, 14.78146741, 14.71224598, 14.6804352 , 14.67004224,
#        14.65042913, 14.56554801, 14.4337005 , 14.10442854, 14.13234474,
#        14.01836004, 14.06790271, 13.97784747, 13.94603315, 13.79815333,
#        13.76177003, 13.68532959, 13.48892917, 13.07632052, 12.779719  ,
#        12.7327968 , 12.6888147 , 12.61323585, 12.51081978, 12.35939329,
#        12.21958651, 11.95769578, 12.21000571, 12.21910477, 12.5607238 ,
#        13.06626627, 13.14385253, 13.08291932, 13.29510939, 13.32416327,
#        13.36668818, 13.39208913, 13.47964036, 13.67145846, 13.61438372,
#        13.73612871, 13.60582178, 14.03571906, 13.99217155, 14.09982232,
#        14.13612592, 14.46463931, 14.6232475 , 14.50980175, 14.53390639,
#        14.53832972, 14.50350391, 14.45590367, 14.39242328, 14.1699777 ,
#        14.01088561, 13.77709561, 13.78349329, 13.7666254 , 13.73008797,
#        13.73328625, 13.7620312 , 13.85212167, 13.71758758, 13.6725205 ,
#        13.64520962, 13.65355613, 13.8098848 , 13.65997686, 13.8016807 ,
#        13.84066275, 13.84904775, 13.86345362, 13.87400371, 13.94254281,
#        13.89706463, 13.89671624, 13.84096524, 13.76633432, 13.63210349,
#        13.53992024, 13.32396088, 13.35991601, 13.60891299, 13.56117739,
#        13.49010661, 13.4786534 , 13.42435701, 13.41359915, 13.205575  ,
#        13.26033456, 13.13169901, 13.237534  , 13.19627121, 13.0766878 ,
#        13.13505103, 13.16036429, 13.35634326, 13.38942927, 13.34196597,
#        13.3731904 , 13.38934847, 13.62255968, 13.52037556, 13.46955126,
#        13.34619772, 13.5525164 , 13.53971629, 13.59082997, 13.77835793,
#        13.88516779, 13.93743455, 14.15386833, 14.3977465 , 14.49611051,
#        14.81504935, 14.96925219, 14.7095977 , 15.08433645, 15.59137155,
#        16.17622769, 16.65229851, 17.30563372, 18.36149313, 18.30797831,
#        17.51210846, 17.66766829, 17.96203878, 17.74000071, 17.68188312,
#        17.18505701, 17.15987549, 17.09993934, 17.22233261, 17.16051802,
#        17.01217829, 16.82273592, 16.53123326, 16.31100445, 16.35551105,
#        16.37580872, 16.37575353, 16.31257696, 16.23302558, 16.01361022,
#        15.99133254, 15.99395687, 15.955128  , 15.8580287 , 15.85862052,
#        16.11120561, 16.47959599, 17.01563814, 16.99859963, 17.06651886,
#        17.17619967, 17.37506341, 17.79704867, 18.02663594, 18.42925794,
#        17.85220338, 17.90337721, 17.97238033, 18.43292177, 18.25685868,
#        18.12883799, 18.07047528, 18.15366653, 18.14258825, 18.17870919,
#        18.34665633, 18.29663078, 18.14968868, 18.14991474, 18.1859215 ,
#        18.18686145, 18.25323526, 18.30509021, 18.41240484, 18.48627779,
#        18.10045114, 18.12181871, 18.0306005 , 17.87679978, 17.46069427,
#        17.56465608, 17.5759132 , 17.49256253, 17.42528206, 17.29639655,
#        17.34379942, 17.28962861, 17.26227213, 17.10484949, 17.06734292,
#        17.02958747, 16.95765345, 16.91392548, 16.70467965, 16.49931318,
#        16.43378471, 16.24014969, 16.1745099 , 15.98637059, 15.7116837 ,
#        15.43877644, 15.56453984, 15.89697429, 15.68406184, 15.31168443,
#        15.13059035, 14.71318473, 15.03557521, 14.81310694, 14.85141118,
#        14.81993104, 14.78899415, 14.68004031, 14.66185624, 14.75563395,
#        14.80246008, 14.86269562, 14.88712125, 14.88675493, 14.91716393,
#        14.87376543, 14.81330455, 14.75428766, 14.60432325, 14.60411786,
#        14.60160841, 14.7245211 , 14.70207436, 14.72270983, 14.85231209,
#        14.78426774, 14.86758674, 15.06472358, 15.14593487, 14.98272895,
#        15.23483709, 15.28867474, 15.20578815, 15.20144236, 15.17182957,
#        15.0579048 , 15.08312594, 15.07075303, 15.12778131, 15.07195135,
#        15.07230366, 15.02770508, 15.02576074, 15.01476588, 15.01125568,
#        15.01256575, 14.98639129, 14.97763775, 15.06819594, 15.26516278,
#        15.38306917, 15.31299977, 15.5073019 , 15.52760431, 15.79092299,
#        15.82266137, 16.10459075, 16.14064207, 16.45419638, 16.62799716,
#        17.05698556, 16.9621102 , 16.63173292, 16.66395187, 16.4633427 ,
#        16.39382491, 15.93709883, 15.9264395 , 15.67714061, 15.57855346,
#        15.49679302, 15.38527604, 15.25697558, 15.11021111, 15.01025328,
#        14.90805022, 14.9346213 , 14.87873938, 14.82491267, 14.68737042,
#        14.56425252, 14.62415819, 15.03098055, 15.22037893, 15.21921561,
#        15.43154646, 15.85125954, 16.09695382, 16.38145353, 17.10116115,
#        16.70750035, 16.94243745, 17.06641905, 17.24766236, 17.50846815,
#        17.50806298, 17.54587923, 17.49384921, 17.33676846, 17.32235405,
#        17.36405278, 17.30530737, 17.42682787, 17.50961997, 17.6734684 ,
#        17.72871593, 17.81751168, 17.93764911, 18.05640848, 18.1521235 ,
#        18.13946902, 18.30610778, 18.55497849, 18.56941964, 18.81122589,
#        18.86159776, 18.8255934 , 18.8444774 , 18.82469806, 18.73482977,
#        18.73225953, 18.33923456, 18.01469905, 17.73722002, 18.01377206,
#        18.06774479, 18.38080755, 18.07387616, 17.9858479 , 17.94671885,
#        17.8645615 , 17.87452047, 18.06122251, 18.15717102, 18.43344729,
#        18.538122  , 18.70554379, 18.63144828, 18.63386254, 18.57315536,
#        18.45139018, 18.2396353 , 18.22926408, 18.09943507, 18.17870732,
#        17.69588867, 17.96711082, 18.02481703, 18.05133739, 17.98615125,
#        17.96700047, 17.94592984, 17.92659397, 17.90996548, 17.89282097,
#        17.87769717, 17.86857642, 17.86661422, 17.87383367])

# %%
## Performance accuracy (Avg Hybrid) for last n days
print('mse=', mean_squared_error(test_prices[-n:], arith_pred[-n:]))
print('rmse=', root_mean_squared_error(test_prices[-n:], arith_pred[-n:]))
print('mae=', mean_absolute_error(test_prices[-n:], arith_pred[-n:]))
print('mape=', mean_absolute_percentage_error(test_prices[-n:], arith_pred[-n:]))
# print('r2=', r2_score(test_prices[-n:], arith_pred[-n:]))
# Out:
# mse= 0.06050972662869117
# rmse= 0.24598724891483942
# mae= 0.15462205325485173
# mape= 0.008784967868935857

# %%
n
# Out:
# 15

# %%
## Arithmetic Avg Hybrid predictions
plt.figure(figsize= (20,10))
plt.plot(test_prices, color= 'blue', label= 'Actual Prices', linestyle= '--', marker= 'o')
plt.plot(arith_pred, color= 'green', label= 'Predicted Prices (Arithmetic Avg Hybrid)', linestyle= '--', marker= 'o')
# plt.plot(test_arima_prices, color= 'red', label= 'Predicted Prices (ARIMA)')

plt.xlim(len(arith_pred)-n-5, len(arith_pred))
plt.axvline(x= len(test_prices)-n, color= 'red', linestyle= '--', label= 'Out-of-Sample line')


plt.ylabel('Closing Prices')
plt.grid()
plt.legend()

# %% [markdown]
# ### Weighted Average

# %%
## Grid search method to determine best alpha
best_mse, best_alpha= float('inf'), None
for w in np.linspace(0,1,101):
    combined= np.add(w * test_arima_prices, (1-w)* test_lstm_prices) 
    mse= mean_squared_error(test_prices, combined)
    if mse< best_mse:
        best_mse, best_alpha= mse, w

weight_pred= np.add(best_alpha * test_arima_prices, (1-best_alpha)* test_lstm_prices)
print('Lowest MSE:', best_mse)
print('Best Alpha:', best_alpha)
# Out:
# Lowest MSE: 0.14998566793643703
# Best Alpha: 0.79

# %%
## Performance accuracy (Weighted Hybrid) for last n days
print('mse=', mean_squared_error(test_prices[-n:], weight_pred[-n:]))
print('rmse=', root_mean_squared_error(test_prices[-n:], weight_pred[-n:]))
print('mae=', mean_absolute_error(test_prices[-n:], weight_pred[-n:]))
print('mape=', mean_absolute_percentage_error(test_prices[-n:], weight_pred[-n:]))
# print('r2=', r2_score(test_prices[-n:], weight_pred[-n:]))
# Out:
# mse= 0.07824760146837097
# rmse= 0.2797277273857044
# mae= 0.2074668090364452
# mape= 0.011765263215115025

# %%
## Weighted Avg Hybrid predictions
plt.figure(figsize= (15,8))
plt.plot(test_prices, color= 'blue', label= 'Actual Prices', linestyle= '--', marker= 'o')
plt.plot(weight_pred, color= 'green', label= 'Predicted Prices (Weighted Avg Hybrid)', linestyle= '--', marker= 'o')
# plt.plot(test_arima_prices, color= 'red', label= 'Predicted Prices (ARIMA)')

plt.xlim(len(weight_pred)-n-5, len(weight_pred))
plt.axvline(x= len(test_prices)-n, color= 'red', linestyle= '--', label= 'Out-of-Sample line')



plt.ylabel('Closing Prices')
plt.grid()
plt.legend()
